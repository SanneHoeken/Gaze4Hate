# %%
#!pip install --upgrade pip
#!pip install datasets
#!pip install tensorboard
#!pip install transformers

# %% [markdown]
# ## All other imports are here:

# %%
from dataclasses import dataclass, field
import json
import logging
import os
from typing import Optional

from math import isnan

import random

import numpy as np
import pandas as pd
import torch
from transformers import AutoTokenizer, AutoConfig, Trainer, EvalPrediction, set_seed
from transformers.training_args import TrainingArguments

# %% [markdown]
# ------------------------------

# %%
## Gaze4Hate dataset
filename = "../processed_data/click_output_data_Jan24.csv"
gaze_df = pd.read_csv(filename)#
gaze_df.drop(gaze_df.filter(regex="Unname"), axis=1, inplace=True)
gaze_df.head(5)
# Out:
#    IP_INDEX                IP_LABEL RECORDING_SESSION_LABEL  TRIAL_INDEX  \
# 0         1  Assertion_Image_Period                      p1            5
# 1         1  Assertion_Image_Period                      p1            5
# 2         1  Assertion_Image_Period                      p1            5
# 3         1  Assertion_Image_Period                      p1            5
# 4         1  Assertion_Image_Period                      p1            5
#
#    IA_AVERAGE_FIX_PUPIL_SIZE  TRIAL_DWELL_TIME  TRIAL_FIXATION_COUNT  \
# 0                     931.00            6522.0                    30
# 1                     950.00            6522.0                    30
# 2                     901.00            6522.0                    30
# 3                     945.50            6522.0                    30
# 4                     946.43            6522.0                    30
#
#    TRIAL_IA_COUNT TRIAL_LABEL  IA_FIXATION_%  ...  forward_reg_list  \
# 0              13    Trial: 5         0.1000  ...         [3, 2, 2]
# 1              13    Trial: 5         0.1000  ...            [4, 4]
# 2              13    Trial: 5         0.1000  ...               [4]
# 3              13    Trial: 5         0.2000  ...      [6, 5, 5, 5]
# 4              13    Trial: 5         0.2333  ...            [6, 6]
#
#   total_reg_list  backward_reg_count  forward_reg_count  total_reg_count  \
# 0      [3, 2, 2]                 0.0                3.0              3.0
# 1      [1, 4, 4]                 1.0                2.0              3.0
# 2      [1, 4, 1]                 2.0                1.0              3.0
# 3   [6, 5, 5, 5]                 0.0                4.0              4.0
# 4      [6, 3, 6]                 1.0                2.0              3.0
#
#   Clicked        token  Intensity_Category  Intensity_Category_Binary  \
# 0   False       frauen                hate                       hate
# 1   False        haben                hate                       hate
# 2   False        einen                hate                       hate
# 3    True  signifikant                hate                       hate
# 4    True   geringeren                hate                       hate
#
#    Pupilsize_variation
# 0                 68.0
# 1                111.0
# 2                 55.0
# 3                146.0
# 4                166.0
#
# [5 rows x 65 columns]

# %%
gaze_df.loc[(gaze_df['RECORDING_SESSION_LABEL']=="p1") & (gaze_df['TRIAL_INDEX']==6), 'IA_DWELL_TIME']
# Out:
# 6     649
# 7     525
# 8     636
# 9       0
# 10    543
# 11    304
# 12    223
# 13    141
# Name: IA_DWELL_TIME, dtype: int64

# %%
### There are words which are not fixated, while sentence level paramaters like TRIAL_DWELL_TIME, TRIAL_FIXATION_COUNT are calculated, some of the parameters are NaN
### to be able to run them with the ML models, we need to fill them with average or drop the entire row, but droping also introduces some other problems

avg_col_for_nan= ['IA_AVERAGE_FIX_PUPIL_SIZE', 'IA_MAX_FIX_PUPIL_SIZE','IA_MIN_FIX_PUPIL_SIZE', 'Pupilsize_variation','IA_FIRST_FIXATION_DURATION', 'IA_SECOND_FIXATION_DURATION', 'IA_SECOND_RUN_FIXATION_%','IA_FIRST_RUN_FIXATION_%']
 
zero_col_for_nan=['IA_REGRESSION_IN', 'IA_RUN_COUNT', 'IA_REGRESSION_IN_COUNT','IA_REGRESSION_OUT', 'IA_REGRESSION_OUT_COUNT', 'backward_reg_count', 'forward_reg_count', 'total_reg_count']

empty_list_for_nan = ['backward_reg_list', 'forward_reg_list', 'total_reg_list']


grouped_df_nans = gaze_df.groupby(['RECORDING_SESSION_LABEL', 'TRIAL_INDEX'], dropna=False)

to_change_values_dict= dict()
for group_name in grouped_df_nans.groups.keys(): # sample key : ('p1', 5)
    col_dict= dict()
    #print('Processing : ',group_name, type(group_name))
    trial_df = grouped_df_nans.get_group(group_name)
    for avg_col in avg_col_for_nan:
        col_dict[avg_col] = trial_df[avg_col].mean()
    for zero_col in zero_col_for_nan:
        col_dict[zero_col] = 0      
    for empty_col in empty_list_for_nan:
        col_dict[empty_col] = []     
    to_change_values_dict[group_name] = col_dict
    
to_change_values_dict # to_change_values_dict['p1', 5]
# Out:
# {('p1', 5): {'IA_AVERAGE_FIX_PUPIL_SIZE': 928.465,
#   'IA_MAX_FIX_PUPIL_SIZE': 979.3333333333334,
#   'IA_MIN_FIX_PUPIL_SIZE': 876.6666666666666,
#   'Pupilsize_variation': 102.66666666666667,
#   'IA_FIRST_FIXATION_DURATION': 159.0,
#   'IA_SECOND_FIXATION_DURATION': 223.66666666666666,
#   'IA_SECOND_RUN_FIXATION_%': 0.03886666666666667,
#   'IA_FIRST_RUN_FIXATION_%': 0.049983333333333345,
#   'IA_REGRESSION_IN': 0,
#   'IA_RUN_COUNT': 0,
#   'IA_REGRESSION_IN_COUNT': 0,
#   'IA_REGRESSION_OUT': 0,
#   'IA_REGRESSION_OUT_COUNT': 0,
#   'backward_reg_count': 0,
#   'forward_reg_count': 0,
#   'total_reg_count': 0,
#   'backward_reg_list': [],
#   'forward_reg_list': [],
#   'total_reg_list': []},
#  ('p1', 6): {'IA_AVERAGE_FIX_PUPIL_SIZE': 923.5714285714286,
#   'IA_MAX_FIX_PUPIL_SIZE': 959.8571428571429,
#   'IA_MIN_FIX_PUPIL_SIZE': 893.2857142857143,
#   'Pupilsize_variation': 66.57142857142857,
#   'IA_FIRST_FIXATION_DURATION': 162.57142857142858,
#   'IA_SECOND_FIXATION_DURATION': 215.4,
#   'IA_SECOND_RUN_FIXATION_%': 0.055600000000000004,
#   'IA_FIRST_RUN_FIXATION_%': 0.06352857142857142,
#   'IA_REGRESSION_IN': 0,
#   'IA_RUN_COUNT': 0,
#   'IA_REGRESSION_IN_COUNT': 0,
#   'IA_REGRESSION_OUT': 0,
#   'IA_REGRESSION_OUT_COUNT': 0,
#   'backward_reg_count': 0,
#   'forward_reg_count': 0,
#   'total_reg_count': 0,
#   'backward_reg_list': [],
#   'forward_reg_list': [],
#   'total_reg_list': []},
#  ('p1', 7): {'IA_AVERAGE_FIX_PUPIL_SIZE': 820.6428571428571,
#   'IA_MAX_FIX_PUPIL_SIZE': 840.8571428571429,
#   'IA_MIN_FIX_PUPIL_SIZE': 801.1428571428571,
#   'Pupilsize_variation': 39.714285714285715,
#   'IA_FIRST_FIXATION_DURATION': 175.71428571428572,
#   'IA_SECOND_FIXATION_DURATION': 259.8333333333333,
#   'IA_SECOND_RUN_FIXATION_%': 0.07056,
#   'IA_FIRST_RUN_FIXATION_%': 0.0756,
#   'IA_REGRESSION_IN': 0,
#   'IA_RUN_COUNT': 0,
#   'IA_REGRESSION_IN_COUNT': 0,
#   'IA_REGRESSION_OUT': 0,
#   'IA_REGRESSION_OUT_COUNT': 0,
#   'backward_reg_count': 0,
#   'forward_reg_count': 0,
#   'total_reg_count': 0,
#   'backward_reg_list': [],
#   'forward_reg_list': [],
#   'total_reg_list': []},
#  ('p1', 8): {'IA_AVERAGE_FIX_PUPIL_SIZE': 850.85,
#   'IA_MAX_FIX_PUPIL_SIZE': 884.6666666666666,
#   'IA_MIN_FIX_PUPIL_SIZE': 799.8333333333334,
#   'Pupilsize_variation': 84.83333333333333,
#   'IA_FIRST_FIXATION_DURATION': 161.5,
#   'IA_SECOND_FIXATION_DURATION': 146.75,
#   'IA_SECOND_RUN_FIXATION_%': 0.0921,
#   'IA_FIRST_RUN_FIXATION_%': 0.0526,
#   'IA_REGRESSION_IN': 0,
#   'IA_RUN_COUNT': 0,
#   'IA_REGRESSION_IN_COUNT': 0,
#   'IA_REGRESSION_OUT': 0,
#   'IA_REGRESSION_OUT_COUNT': 0,
#   'backward_reg_count': 0,
#   'forward_reg_count': 0,
#   'total_reg_count': 0,
#   'backward_reg_list': [],
#   'forward_reg_list': [],
#   'total_reg_list': []},
#  ('p1', 9): {'IA_AVERAGE_FIX_PUPIL_SIZE': 859.9285714285714,
#   'IA_MAX_FIX_PUPIL_SIZE': 868.2857142857143,
#   'IA_MIN_FIX_PUPIL_SIZE': 851.5714285714286,
#   'Pupilsize_variation': 16.714285714285715,
#   'IA_FIRST_FIXATION_DURATION': 153.42857142857142,
#   'IA_SECOND_FIXATION_DURATION': 362.0,
#   'IA_SECOND_RUN_FIXATION_%': 0.0714,
#   'IA_FIRST_RUN_FIXATION_%': 0.0714,
#   'IA_REGRESSION_IN': 0,
#   'IA_RUN_COUNT': 0,
#   'IA_REGRESSION_IN_COUNT': 0,
#   'IA_REGRESSION_OUT': 0,
#   'IA_REGRESSION_OUT_COUNT': 0,
#   'backward_reg_count': 0,
#   'forward_reg_count': 0,
#   'total_reg_count': 0,
#   'backward_reg_list': [],
#   'forward_reg_list': [],
#   'total_reg_list': []},
#  ('p1', 10): {'IA_AVERAGE_FIX_PUPIL_SIZE': 795.6,
#   'IA_MAX_FIX_PUPIL_SIZE': 810.4,
#   'IA_MIN_FIX_PUPIL_SIZE': 772.6,
#   'Pupilsize_variation': 37.8,
#   'IA_FIRST_FIXATION_DURATION': 186.0,
#   'IA_SECOND_FIXATION_DURATION': 205.66666666666666,
#   'IA_SECOND_RUN_FIXATION_%': 0.0385,
#   'IA_FIRST_RUN_FIXATION_%': 0.0385,
#   'IA_REGRESSION_IN': 0,
#   'IA_RUN_COUNT': 0,
#   'IA_REGRESSION_IN_COUNT': 0,
#   'IA_REGRESSION_OUT': 0,
#   'IA_REGRESSION_OUT_COUNT': 0,
#   'backward_reg_count': 0,
#   'forward_reg_count': 0,
#   'total_reg_count': 0,
#   'backward_reg_list': [],
#   'forward_reg_list': [],
#   'total_reg_list': []},
#  ('p1', 11): {'IA_AVERAGE_FIX_PUPIL_SIZE': 828.0416666666666,
#   'IA_MAX_FIX_PUPIL_SIZE': 834.0,
#   'IA_MIN_FIX_PUPIL_SIZE': 821.5,
#   'Pupilsize_variation': 12.5,
#   'IA_FIRST_FIXATION_DURATION': 246.33333333333334,
#   'IA_SECOND_FIXATION_DURATION': 259.5,
#   'IA_SECOND_RUN_FIXATION_%': 0.0556,
#   'IA_FIRST_RUN_FIXATION_%': 0.055600000000000004,
#   'IA_REGRESSION_IN': 0,
#   'IA_RUN_COUNT': 0,
#   'IA_REGRESSION_IN_COUNT': 0,
#   'IA_REGRESSION_OUT': 0,
#   'IA_REGRESSION_OUT_COUNT': 0,
#   'backward_reg_count': 0,
#   'forward_reg_count': 0,
#   'total_reg_count': 0,
#   'backward_reg_list': [],
#   'forward_reg_list': [],
#   'total_reg_list': []},
#  ('p1', 12): {'IA_AVERAGE_FIX_PUPIL_SIZE': 787.9433333333333,
#   'IA_MAX_FIX_PUPIL_SIZE': 808.3333333333334,
#   'IA_MIN_FIX_PUPIL_SIZE': 771.0,
#   'Pupilsize_variation': 37.333333333333336,
#   'IA_FIRST_FIXATION_DURATION': 165.66666666666666,
#   'IA_SECOND_FIXATION_DURATION': 227.66666666666666,
#   'IA_SECOND_RUN_FIXATION_%': 0.0667,
#   'IA_FIRST_RUN_FIXATION_%': 0.1333,
#   'IA_REGRESSION_IN': 0,
#   'IA_RUN_COUNT': 0,
#   'IA_REGRESSION_IN_COUNT': 0,
#   'IA_REGRESSION_OUT': 0,
#   'IA_REGRESSION_OUT_COUNT': 0,
#   'backward_reg_count': 0,
#   'forward_reg_count': 0,
#   'total_reg_count': 0,
#   'backward_reg_list': [],
#   'forward_reg_list': [],
#   'total_reg_list': []},
#  ('p1', 13): {'IA_AVERAGE_FIX_PUPIL_SIZE': 855.4275,
#   'IA_MAX_FIX_PUPIL_SIZE': 899.0,
#   'IA_MIN_FIX_PUPIL_SIZE': 823.0,
#   'Pupilsize_variation': 76.0,
#   'IA_FIRST_FIXATION_DURATION': 203.5,
#   'IA_SECOND_FIXATION_DURATION': 204.5,
#   'IA_SECOND_RUN_FIXATION_%': 0.0345,
#   'IA_FIRST_RUN_FIXATION_%': 0.0345,
#   'IA_REGRESSION_IN': 0,
#   'IA_RUN_COUNT': 0,
#   'IA_REGRESSION_IN_COUNT': 0,
#   'IA_REGRESSION_OUT': 0,
#   'IA_REGRESSION_OUT_COUNT': 0,
#   'backward_reg_count': 0,
#   'forward_reg_count': 0,
#   'total_reg_count': 0,
#   'backward_reg_list': [],
#   'forward_reg_list': [],
#   'total_reg_list': []},
#  ('p1', 14): {'IA_AVERAGE_FIX_PUPIL_SIZE': 859.6185714285714,
#   'IA_MAX_FIX_PUPIL_SIZE': 877.5714285714286,
#   'IA_MIN_FIX_PUPIL_SIZE': 843.2857142857143,
#   'Pupilsize_variation': 34.285714285714285,
#   'IA_FIRST_FIXATION_DURATION': 173.85714285714286,
#   'IA_SECOND_FIXATION_DURATION': 249.0,
#   'IA_SECOND_RUN_FIXATION_%': 0.0435,
#   'IA_FIRST_RUN_FIXATION_%': 0.04349999999999999,
#   'IA_REGRESSION_IN': 0,
#   'IA_RUN_COUNT': 0,
#   'IA_REGRESSION_IN_COUNT': 0,
#   'IA_REGRESSION_OUT': 0,
#   'IA_REGRESSION_OUT_COUNT': 0,
#   'backward_reg_count': 0,
#   'forward_reg_count': 0,
#   'total_reg_count': 0,
#   'backward_reg_list': [],
#   'forward_reg_list': [],
#   'total_reg_list': []},
#  ('p1', 15): {'IA_AVERAGE_FIX_PUPIL_SIZE': 804.89,
#   'IA_MAX_FIX_PUPIL_SIZE': 821.6666666666666,
#   'IA_MIN_FIX_PUPIL_SIZE': 787.6666666666666,
#   'Pupilsize_variation': 34.0,
#   'IA_FIRST_FIXATION_DURATION': 240.33333333333334,
#   'IA_SECOND_FIXATION_DURATION': 238.0,
#   'IA_SECOND_RUN_FIXATION_%': 0.0577,
#   'IA_FIRST_RUN_FIXATION_%': 0.0385,
#   'IA_REGRESSION_IN': 0,
#   'IA_RUN_COUNT': 0,
#   'IA_REGRESSION_IN_COUNT': 0,
#   'IA_REGRESSION_OUT': 0,
#   'IA_REGRESSION_OUT_COUNT': 0,
#   'backward_reg_count': 0,
#   'forward_reg_count': 0,
#   'total_reg_count': 0,
#   'backward_reg_list': [],
#   'forward_reg_list': [],
#   'total_reg_list': []},
#  ('p1', 16): {'IA_AVERAGE_FIX_PUPIL_SIZE': 890.9,
#   'IA_MAX_FIX_PUPIL_SIZE': 908.2,
#   'IA_MIN_FIX_PUPIL_SIZE': 873.6,
#   'Pupilsize_variation': 34.6,
#   'IA_FIRST_FIXATION_DURATION': 158.8,
#   'IA_SECOND_FIXATION_DURATION': 257.5,
#   'IA_SECOND_RUN_FIXATION_%': 0.0526,
#   'IA_FIRST_RUN_FIXATION_%': 0.0526,
#   'IA_REGRESSION_IN': 0,
#   'IA_RUN_COUNT': 0,
#   'IA_REGRESSION_IN_COUNT': 0,
#   'IA_REGRESSION_OUT': 0,
#   'IA_REGRESSION_OUT_COUNT': 0,
#   'backward_reg_count': 0,
#   'forward_reg_count': 0,
#   'total_reg_count': 0,
#   'backward_reg_list': [],
#   'forward_reg_list': [],
#   'total_reg_list': []},
#  ('p1', 17): {'IA_AVERAGE_FIX_PUPIL_SIZE': 849.3333333333334,
#   'IA_MAX_FIX_PUPIL_SIZE': 856.0,
#   'IA_MIN_FIX_PUPIL_SIZE': 843.3333333333334,
#   'Pupilsize_variation': 12.666666666666666,
#   'IA_FIRST_FIXATION_DURATION': 342.3333333333333,
#   'IA_SECOND_FIXATION_DURATION': 331.5,
#   'IA_SECOND_RUN_FIXATION_%': 0.0667,
#   'IA_FIRST_RUN_FIXATION_%': 0.08889999999999999,
#   'IA_REGRESSION_IN': 0,
#   'IA_RUN_COUNT': 0,
#   'IA_REGRESSION_IN_COUNT': 0,
#   'IA_REGRESSION_OUT': 0,
#   'IA_REGRESSION_OUT_COUNT': 0,
#   'backward_reg_count': 0,
#   'forward_reg_count': 0,
#   'total_reg_count': 0,
#   'backward_reg_list': [],
#   'forward_reg_list': [],
#   'total_reg_list': []},
#  ('p1', 18): {'IA_AVERAGE_FIX_PUPIL_SIZE': 833.3616666666667,
#   'IA_MAX_FIX_PUPIL_SIZE': 853.3333333333334,
#   'IA_MIN_FIX_PUPIL_SIZE': 810.5,
#   'Pupilsize_variation': 42.833333333333336,
#   'IA_FIRST_FIXATION_DURATION': 209.33333333333334,
#   'IA_SECOND_FIXATION_DURATION': 187.0,
#   'IA_SECOND_RUN_FIXATION_%': 0.05000000000000001,
#   'IA_FIRST_RUN_FIXATION_%': 0.06666666666666667,
#   'IA_REGRESSION_IN': 0,
#   'IA_RUN_COUNT': 0,
#   'IA_REGRESSION_IN_COUNT': 0,
#   'IA_REGRESSION_OUT': 0,
#   'IA_REGRESSION_OUT_COUNT': 0,
#   'backward_reg_count': 0,
#   'forward_reg_count': 0,
#   'total_reg_count': 0,
#   'backward_reg_list': [],
#   'forward_reg_list': [],
#   'total_reg_list': []},
#  ('p1', 19): {'IA_AVERAGE_FIX_PUPIL_SIZE': 865.875,
#   'IA_MAX_FIX_PUPIL_SIZE': 873.75,
#   'IA_MIN_FIX_PUPIL_SIZE': 858.0,
#   'Pupilsize_variation': 15.75,
#   'IA_FIRST_FIXATION_DURATION': 214.5,
#   'IA_SECOND_FIXATION_DURATION': 281.0,
#   'IA_SECOND_RUN_FIXATION_%': 0.0714,
#   'IA_FIRST_RUN_FIXATION_%': 0.0714,
#   'IA_REGRESSION_IN': 0,
#   'IA_RUN_COUNT': 0,
#   'IA_REGRESSION_IN_COUNT': 0,
#   'IA_REGRESSION_OUT': 0,
#   'IA_REGRESSION_OUT_COUNT': 0,
#   'backward_reg_count': 0,
#   'forward_reg_count': 0,
#   'total_reg_count': 0,
#   'backward_reg_list': [],
#   'forward_reg_list': [],
#   'total_reg_list': []},
#  ('p1', 20): {'IA_AVERAGE_FIX_PUPIL_SIZE': 838.5,
#   'IA_MAX_FIX_PUPIL_SIZE': 850.25,
#   'IA_MIN_FIX_PUPIL_SIZE': 826.75,
#   'Pupilsize_variation': 23.5,
#   'IA_FIRST_FIXATION_DURATION': 156.5,
#   'IA_SECOND_FIXATION_DURATION': 512.0,
#   'IA_SECOND_RUN_FIXATION_%': 0.0909,
#   'IA_FIRST_RUN_FIXATION_%': 0.0909,
#   'IA_REGRESSION_IN': 0,
#   'IA_RUN_COUNT': 0,
#   'IA_REGRESSION_IN_COUNT': 0,
#   'IA_REGRESSION_OUT': 0,
#   'IA_REGRESSION_OUT_COUNT': 0,
#   'backward_reg_count': 0,
#   'forward_reg_count': 0,
#   'total_reg_count': 0,
#   'backward_reg_list': [],
#   'forward_reg_list': [],
#   'total_reg_list': []},
#  ('p1', 21): {'IA_AVERAGE_FIX_PUPIL_SIZE': nan,
#   'IA_MAX_FIX_PUPIL_SIZE': nan,
#   'IA_MIN_FIX_PUPIL_SIZE': nan,
#   'Pupilsize_variation': nan,
#   'IA_FIRST_FIXATION_DURATION': nan,
#   'IA_SECOND_FIXATION_DURATION': nan,
#   'IA_SECOND_RUN_FIXATION_%': nan,
#   'IA_FIRST_RUN_FIXATION_%': nan,
#   'IA_REGRESSION_IN': 0,
#   'IA_RUN_COUNT': 0,
#   'IA_REGRESSION_IN_COUNT': 0,
#   'IA_REGRESSION_OUT': 0,
#   'IA_REGRESSION_OUT_COUNT': 0,
#   'backward_reg_count': 0,
#   'forward_reg_count': 0,
#   'total_reg_count': 0,
#   'backward_reg_list': [],
#   'forward_reg_list': [],
#   'total_reg_list': []},
#  ('p1', 22): {'IA_AVERAGE_FIX_PUPIL_SIZE': 898.8333333333334,
#   'IA_MAX_FIX_PUPIL_SIZE': 919.0,
#   'IA_MIN_FIX_PUPIL_SIZE': 886.6666666666666,
#   'Pupilsize_variation': 32.333333333333336,
#   'IA_FIRST_FIXATION_DURATION': 224.0,
#   'IA_SECOND_FIXATION_DURATION': 152.0,
#   'IA_SECOND_RUN_FIXATION_%': 0.0417,
#   'IA_FIRST_RUN_FIXATION_%': 0.055566666666666674,
#   'IA_REGRESSION_IN': 0,
#   'IA_RUN_COUNT': 0,
#   'IA_REGRESSION_IN_COUNT': 0,
#   'IA_REGRESSION_OUT': 0,
#   'IA_REGRESSION_OUT_COUNT': 0,
#   'backward_reg_count': 0,
#   'forward_reg_count': 0,
#   'total_reg_count': 0,
#   'backward_reg_list': [],
#   'forward_reg_list': [],
#   'total_reg_list': []},
#  ('p1', 23): {'IA_AVERAGE_FIX_PUPIL_SIZE': 888.75,
#   'IA_MAX_FIX_PUPIL_SIZE': 908.5,
#   'IA_MIN_FIX_PUPIL_SIZE': 868.5,
#   'Pupilsize_variation': 40.0,
#   'IA_FIRST_FIXATION_DURATION': 173.0,
#   'IA_SECOND_FIXATION_DURATION': 258.0,
#   'IA_SECOND_RUN_FIXATION_%': 0.0588,
#   'IA_FIRST_RUN_FIXATION_%': 0.0882,
#   'IA_REGRESSION_IN': 0,
#   'IA_RUN_COUNT': 0,
#   'IA_REGRESSION_IN_COUNT': 0,
#   'IA_REGRESSION_OUT': 0,
#   'IA_REGRESSION_OUT_COUNT': 0,
#   'backward_reg_count': 0,
#   'forward_reg_count': 0,
#   'total_reg_count': 0,
#   'backward_reg_list': [],
#   'forward_reg_list': [],
#   'total_reg_list': []},
#  ('p1', 24): {'IA_AVERAGE_FIX_PUPIL_SIZE': 805.75,
#   'IA_MAX_FIX_PUPIL_SIZE': 814.0,
#   'IA_MIN_FIX_PUPIL_SIZE': 795.5,
#   'Pupilsize_variation': 18.5,
#   'IA_FIRST_FIXATION_DURATION': 493.0,
#   'IA_SECOND_FIXATION_DURATION': 148.0,
#   'IA_SECOND_RUN_FIXATION_%': 0.1053,
#   'IA_FIRST_RUN_FIXATION_%': 0.0526,
#   'IA_REGRESSION_IN': 0,
#   'IA_RUN_COUNT': 0,
#   'IA_REGRESSION_IN_COUNT': 0,
#   'IA_REGRESSION_OUT': 0,
#   'IA_REGRESSION_OUT_COUNT': 0,
#   'backward_reg_count': 0,
#   'forward_reg_count': 0,
#   'total_reg_count': 0,
#   'backward_reg_list': [],
#   'forward_reg_list': [],
#   'total_reg_list': []},
#  ('p1', 25): {'IA_AVERAGE_FIX_PUPIL_SIZE': 856.4166666666666,
#   'IA_MAX_FIX_PUPIL_SIZE': 866.1666666666666,
#   'IA_MIN_FIX_PUPIL_SIZE': 846.3333333333334,
#   'Pupilsize_variation': 19.833333333333332,
#   'IA_FIRST_FIXATION_DURATION': 149.5,
#   'IA_SECOND_FIXATION_DURATION': 171.0,
#   'IA_SECOND_RUN_FIXATION_%': 0.0882,
#   'IA_FIRST_RUN_FIXATION_%': 0.0784,
#   'IA_REGRESSION_IN': 0,
#   'IA_RUN_COUNT': 0,
#   'IA_REGRESSION_IN_COUNT': 0,
#   'IA_REGRESSION_OUT': 0,
#   'IA_REGRESSION_OUT_COUNT': 0,
#   'backward_reg_count': 0,
#   'forward_reg_count': 0,
#   'total_reg_count': 0,
#   'backward_reg_list': [],
#   'forward_reg_list': [],
#   'total_reg_list': []},
#  ('p1', 26): {'IA_AVERAGE_FIX_PUPIL_SIZE': 813.5,
#   'IA_MAX_FIX_PUPIL_SIZE': 883.0,
#   'IA_MIN_FIX_PUPIL_SIZE': 744.0,
#   'Pupilsize_variation': 139.0,
#   'IA_FIRST_FIXATION_DURATION': 518.0,
#   'IA_SECOND_FIXATION_DURATION': 511.0,
#   'IA_SECOND_RUN_FIXATION_%': 0.0625,
#   'IA_FIRST_RUN_FIXATION_%': 0.0625,
#   'IA_REGRESSION_IN': 0,
#   'IA_RUN_COUNT': 0,
#   'IA_REGRESSION_IN_COUNT': 0,
#   'IA_REGRESSION_OUT': 0,
#   'IA_REGRESSION_OUT_COUNT': 0,
#   'backward_reg_count': 0,
#   'forward_reg_count': 0,
#   'total_reg_count': 0,
#   'backward_reg_list': [],
#   'forward_reg_list': [],
#   'total_reg_list': []},
#  ('p1', 27): {'IA_AVERAGE_FIX_PUPIL_SIZE': 962.6,
#   'IA_MAX_FIX_PUPIL_SIZE': 1089.0,
#   'IA_MIN_FIX_PUPIL_SIZE': 764.0,
#   'Pupilsize_variation': 325.0,
#   'IA_FIRST_FIXATION_DURATION': 148.0,
#   'IA_SECOND_FIXATION_DURATION': 128.0,
#   'IA_SECOND_RUN_FIXATION_%': 0.0625,
#   'IA_FIRST_RUN_FIXATION_%': 0.25,
#   'IA_REGRESSION_IN': 0,
#   'IA_RUN_COUNT': 0,
#   'IA_REGRESSION_IN_COUNT': 0,
#   'IA_REGRESSION_OUT': 0,
#   'IA_REGRESSION_OUT_COUNT': 0,
#   'backward_reg_count': 0,
#   'forward_reg_count': 0,
#   'total_reg_count': 0,
#   'backward_reg_list': [],
#   'forward_reg_list': [],
#   'total_reg_list': []},
#  ('p1', 28): {'IA_AVERAGE_FIX_PUPIL_SIZE': nan,
#   'IA_MAX_FIX_PUPIL_SIZE': nan,
#   'IA_MIN_FIX_PUPIL_SIZE': nan,
#   'Pupilsize_variation': nan,
#   'IA_FIRST_FIXATION_DURATION': nan,
#   'IA_SECOND_FIXATION_DURATION': nan,
#   'IA_SECOND_RUN_FIXATION_%': nan,
#   'IA_FIRST_RUN_FIXATION_%': nan,
#   'IA_REGRESSION_IN': 0,
#   'IA_RUN_COUNT': 0,
#   'IA_REGRESSION_IN_COUNT': 0,
#   'IA_REGRESSION_OUT': 0,
#   'IA_REGRESSION_OUT_COUNT': 0,
#   'backward_reg_count': 0,
#   'forward_reg_count': 0,
#   'total_reg_count': 0,
#   'backward_reg_list': [],
#   'forward_reg_list': [],
#   'total_reg_list': []},
#  ('p1', 29): {'IA_AVERAGE_FIX_PUPIL_SIZE': 964.625,
#   'IA_MAX_FIX_PUPIL_SIZE': 973.25,
#   'IA_MIN_FIX_PUPIL_SIZE': 956.0,
#   'Pupilsize_variation': 17.25,
#   'IA_FIRST_FIXATION_DURATION': 143.75,
#   'IA_SECOND_FIXATION_DURATION': 246.0,
#   'IA_SECOND_RUN_FIXATION_%': 0.0625,
#   'IA_FIRST_RUN_FIXATION_%': 0.0625,
#   'IA_REGRESSION_IN': 0,
#   'IA_RUN_COUNT': 0,
#   'IA_REGRESSION_IN_COUNT': 0,
#   'IA_REGRESSION_OUT': 0,
#   'IA_REGRESSION_OUT_COUNT': 0,
#   'backward_reg_count': 0,
#   'forward_reg_count': 0,
#   'total_reg_count': 0,
#   'backward_reg_list': [],
#   'forward_reg_list': [],
#   'total_reg_list': []},
#  ('p1', 30): {'IA_AVERAGE_FIX_PUPIL_SIZE': 778.0,
#   'IA_MAX_FIX_PUPIL_SIZE': 778.0,
#   'IA_MIN_FIX_PUPIL_SIZE': 778.0,
#   'Pupilsize_variation': 0.0,
#   'IA_FIRST_FIXATION_DURATION': 157.5,
#   'IA_SECOND_FIXATION_DURATION': nan,
#   'IA_SECOND_RUN_FIXATION_%': nan,
#   'IA_FIRST_RUN_FIXATION_%': 0.0476,
#   'IA_REGRESSION_IN': 0,
#   'IA_RUN_COUNT': 0,
#   'IA_REGRESSION_IN_COUNT': 0,
#   'IA_REGRESSION_OUT': 0,
#   'IA_REGRESSION_OUT_COUNT': 0,
#   'backward_reg_count': 0,
#   'forward_reg_count': 0,
#   'total_reg_count': 0,
#   'backward_reg_list': [],
#   'forward_reg_list': [],
#   'total_reg_list': []},
#  ('p1', 31): {'IA_AVERAGE_FIX_PUPIL_SIZE': nan,
#   'IA_MAX_FIX_PUPIL_SIZE': nan,
#   'IA_MIN_FIX_PUPIL_SIZE': nan,
#   'Pupilsize_variation': nan,
#   'IA_FIRST_FIXATION_DURATION': nan,
#   'IA_SECOND_FIXATION_DURATION': nan,
#   'IA_SECOND_RUN_FIXATION_%': nan,
#   'IA_FIRST_RUN_FIXATION_%': nan,
#   'IA_REGRESSION_IN': 0,
#   'IA_RUN_COUNT': 0,
#   'IA_REGRESSION_IN_COUNT': 0,
#   'IA_REGRESSION_OUT': 0,
#   'IA_REGRESSION_OUT_COUNT': 0,
#   'backward_reg_count': 0,
#   'forward_reg_count': 0,
#   'total_reg_count': 0,
#   'backward_reg_list': [],
#   'forward_reg_list': [],
#   'total_reg_list': []},
#  ('p1', 32): {'IA_AVERAGE_FIX_PUPIL_SIZE': nan,
#   'IA_MAX_FIX_PUPIL_SIZE': nan,
#   'IA_MIN_FIX_PUPIL_SIZE': nan,
#   'Pupilsize_variation': nan,
#   'IA_FIRST_FIXATION_DURATION': nan,
#   'IA_SECOND_FIXATION_DURATION': nan,
#   'IA_SECOND_RUN_FIXATION_%': nan,
#   'IA_FIRST_RUN_FIXATION_%': nan,
#   'IA_REGRESSION_IN': 0,
#   'IA_RUN_COUNT': 0,
#   'IA_REGRESSION_IN_COUNT': 0,
#   'IA_REGRESSION_OUT': 0,
#   'IA_REGRESSION_OUT_COUNT': 0,
#   'backward_reg_count': 0,
#   'forward_reg_count': 0,
#   'total_reg_count': 0,
#   'backward_reg_list': [],
#   'forward_reg_list': [],
#   'total_reg_list': []},
#  ('p1', 33): {'IA_AVERAGE_FIX_PUPIL_SIZE': 952.0,
#   'IA_MAX_FIX_PUPIL_SIZE': 952.0,
#   'IA_MIN_FIX_PUPIL_SIZE': 952.0,
#   'Pupilsize_variation': 0.0,
#   'IA_FIRST_FIXATION_DURATION': 336.0,
#   'IA_SECOND_FIXATION_DURATION': nan,
#   'IA_SECOND_RUN_FIXATION_%': nan,
#   'IA_FIRST_RUN_FIXATION_%': 0.0667,
#   'IA_REGRESSION_IN': 0,
#   'IA_RUN_COUNT': 0,
#   'IA_REGRESSION_IN_COUNT': 0,
#   'IA_REGRESSION_OUT': 0,
#   'IA_REGRESSION_OUT_COUNT': 0,
#   'backward_reg_count': 0,
#   'forward_reg_count': 0,
#   'total_reg_count': 0,
#   'backward_reg_list': [],
#   'forward_reg_list': [],
#   'total_reg_list': []},
#  ('p1', 34): {'IA_AVERAGE_FIX_PUPIL_SIZE': 805.0,
#   'IA_MAX_FIX_PUPIL_SIZE': 818.6666666666666,
#   'IA_MIN_FIX_PUPIL_SIZE': 791.3333333333334,
#   'Pupilsize_variation': 27.333333333333332,
#   'IA_FIRST_FIXATION_DURATION': 225.66666666666666,
#   'IA_SECOND_FIXATION_DURATION': 162.0,
#   'IA_SECOND_RUN_FIXATION_%': 0.037,
#   'IA_FIRST_RUN_FIXATION_%': 0.037,
#   'IA_REGRESSION_IN': 0,
#   'IA_RUN_COUNT': 0,
#   'IA_REGRESSION_IN_COUNT': 0,
#   'IA_REGRESSION_OUT': 0,
#   'IA_REGRESSION_OUT_COUNT': 0,
#   'backward_reg_count': 0,
#   'forward_reg_count': 0,
#   'total_reg_count': 0,
#   'backward_reg_list': [],
#   'forward_reg_list': [],
#   'total_reg_list': []},
#  ('p1', 35): {'IA_AVERAGE_FIX_PUPIL_SIZE': nan,
#   'IA_MAX_FIX_PUPIL_SIZE': nan,
#   'IA_MIN_FIX_PUPIL_SIZE': nan,
#   'Pupilsize_variation': nan,
#   'IA_FIRST_FIXATION_DURATION': nan,
#   'IA_SECOND_FIXATION_DURATION': nan,
#   'IA_SECOND_RUN_FIXATION_%': nan,
#   'IA_FIRST_RUN_FIXATION_%': nan,
#   'IA_REGRESSION_IN': 0,
#   'IA_RUN_COUNT': 0,
#   'IA_REGRESSION_IN_COUNT': 0,
#   'IA_REGRESSION_OUT': 0,
#   'IA_REGRESSION_OUT_COUNT': 0,
#   'backward_reg_count': 0,
#   'forward_reg_count': 0,
#   'total_reg_count': 0,
#   'backward_reg_list': [],
#   'forward_reg_list': [],
#   'total_reg_list': []},
#  ('p1', 36): {'IA_AVERAGE_FIX_PUPIL_SIZE': 1009.0,
#   'IA_MAX_FIX_PUPIL_SIZE': 1009.0,
#   'IA_MIN_FIX_PUPIL_SIZE': 1009.0,
#   'Pupilsize_variation': 0.0,
#   'IA_FIRST_FIXATION_DURATION': 127.0,
#   'IA_SECOND_FIXATION_DURATION': nan,
#   'IA_SECOND_RUN_FIXATION_%': nan,
#   'IA_FIRST_RUN_FIXATION_%': 0.0667,
#   'IA_REGRESSION_IN': 0,
#   'IA_RUN_COUNT': 0,
#   'IA_REGRESSION_IN_COUNT': 0,
#   'IA_REGRESSION_OUT': 0,
#   'IA_REGRESSION_OUT_COUNT': 0,
#   'backward_reg_count': 0,
#   'forward_reg_count': 0,
#   'total_reg_count': 0,
#   'backward_reg_list': [],
#   'forward_reg_list': [],
#   'total_reg_list': []},
#  ('p1', 37): {'IA_AVERAGE_FIX_PUPIL_SIZE': 923.2233333333334,
#   'IA_MAX_FIX_PUPIL_SIZE': 947.3333333333334,
#   'IA_MIN_FIX_PUPIL_SIZE': 899.6666666666666,
#   'Pupilsize_variation': 47.666666666666664,
#   'IA_FIRST_FIXATION_DURATION': 169.33333333333334,
#   'IA_SECOND_FIXATION_DURATION': 211.5,
#   'IA_SECOND_RUN_FIXATION_%': 0.0294,
#   'IA_FIRST_RUN_FIXATION_%': 0.0392,
#   'IA_REGRESSION_IN': 0,
#   'IA_RUN_COUNT': 0,
#   'IA_REGRESSION_IN_COUNT': 0,
#   'IA_REGRESSION_OUT': 0,
#   'IA_REGRESSION_OUT_COUNT': 0,
#   'backward_reg_count': 0,
#   'forward_reg_count': 0,
#   'total_reg_count': 0,
#   'backward_reg_list': [],
#   'forward_reg_list': [],
#   'total_reg_list': []},
#  ('p1', 38): {'IA_AVERAGE_FIX_PUPIL_SIZE': 872.6666666666666,
#   'IA_MAX_FIX_PUPIL_SIZE': 872.6666666666666,
#   'IA_MIN_FIX_PUPIL_SIZE': 872.6666666666666,
#   'Pupilsize_variation': 0.0,
#   'IA_FIRST_FIXATION_DURATION': 222.0,
#   'IA_SECOND_FIXATION_DURATION': nan,
#   'IA_SECOND_RUN_FIXATION_%': nan,
#   'IA_FIRST_RUN_FIXATION_%': 0.0667,
#   'IA_REGRESSION_IN': 0,
#   'IA_RUN_COUNT': 0,
#   'IA_REGRESSION_IN_COUNT': 0,
#   'IA_REGRESSION_OUT': 0,
#   'IA_REGRESSION_OUT_COUNT': 0,
#   'backward_reg_count': 0,
#   'forward_reg_count': 0,
#   'total_reg_count': 0,
#   'backward_reg_list': [],
#   'forward_reg_list': [],
#   'total_reg_list': []},
#  ('p1', 39): {'IA_AVERAGE_FIX_PUPIL_SIZE': nan,
#   'IA_MAX_FIX_PUPIL_SIZE': nan,
#   'IA_MIN_FIX_PUPIL_SIZE': nan,
#   'Pupilsize_variation': nan,
#   'IA_FIRST_FIXATION_DURATION': nan,
#   'IA_SECOND_FIXATION_DURATION': nan,
#   'IA_SECOND_RUN_FIXATION_%': nan,
#   'IA_FIRST_RUN_FIXATION_%': nan,
#   'IA_REGRESSION_IN': 0,
#   'IA_RUN_COUNT': 0,
#   'IA_REGRESSION_IN_COUNT': 0,
#   'IA_REGRESSION_OUT': 0,
#   'IA_REGRESSION_OUT_COUNT': 0,
#   'backward_reg_count': 0,
#   'forward_reg_count': 0,
#   'total_reg_count': 0,
#   'backward_reg_list': [],
#   'forward_reg_list': [],
#   'total_reg_list': []},
#  ('p1', 40): {'IA_AVERAGE_FIX_PUPIL_SIZE': 861.0,
#   'IA_MAX_FIX_PUPIL_SIZE': 865.3333333333334,
#   'IA_MIN_FIX_PUPIL_SIZE': 856.6666666666666,
#   'Pupilsize_variation': 8.666666666666666,
#   'IA_FIRST_FIXATION_DURATION': 201.83333333333334,
#   'IA_SECOND_FIXATION_DURATION': 128.0,
#   'IA_SECOND_RUN_FIXATION_%': 0.0714,
#   'IA_FIRST_RUN_FIXATION_%': 0.0714,
#   'IA_REGRESSION_IN': 0,
#   'IA_RUN_COUNT': 0,
#   'IA_REGRESSION_IN_COUNT': 0,
#   'IA_REGRESSION_OUT': 0,
#   'IA_REGRESSION_OUT_COUNT': 0,
#   'backward_reg_count': 0,
#   'forward_reg_count': 0,
#   'total_reg_count': 0,
#   'backward_reg_list': [],
#   'forward_reg_list': [],
#   'total_reg_list': []},
#  ('p1', 41): {'IA_AVERAGE_FIX_PUPIL_SIZE': nan,
#   'IA_MAX_FIX_PUPIL_SIZE': nan,
#   'IA_MIN_FIX_PUPIL_SIZE': nan,
#   'Pupilsize_variation': nan,
#   'IA_FIRST_FIXATION_DURATION': nan,
#   'IA_SECOND_FIXATION_DURATION': nan,
#   'IA_SECOND_RUN_FIXATION_%': nan,
#   'IA_FIRST_RUN_FIXATION_%': nan,
#   'IA_REGRESSION_IN': 0,
#   'IA_RUN_COUNT': 0,
#   'IA_REGRESSION_IN_COUNT': 0,
#   'IA_REGRESSION_OUT': 0,
#   'IA_REGRESSION_OUT_COUNT': 0,
#   'backward_reg_count': 0,
#   'forward_reg_count': 0,
#   'total_reg_count': 0,
#   'backward_reg_list': [],
#   'forward_reg_list': [],
#   'total_reg_list': []},
#  ('p1', 42): {'IA_AVERAGE_FIX_PUPIL_SIZE': 930.0,
#   'IA_MAX_FIX_PUPIL_SIZE': 930.0,
#   'IA_MIN_FIX_PUPIL_SIZE': 930.0,
#   'Pupilsize_variation': 0.0,
#   'IA_FIRST_FIXATION_DURATION': 169.0,
#   'IA_SECOND_FIXATION_DURATION': nan,
#   'IA_SECOND_RUN_FIXATION_%': nan,
#   'IA_FIRST_RUN_FIXATION_%': 0.0625,
#   'IA_REGRESSION_IN': 0,
#   'IA_RUN_COUNT': 0,
#   'IA_REGRESSION_IN_COUNT': 0,
#   'IA_REGRESSION_OUT': 0,
#   'IA_REGRESSION_OUT_COUNT': 0,
#   'backward_reg_count': 0,
#   'forward_reg_count': 0,
#   'total_reg_count': 0,
#   'backward_reg_list': [],
#   'forward_reg_list': [],
#   'total_reg_list': []},
#  ('p1', 43): {'IA_AVERAGE_FIX_PUPIL_SIZE': nan,
#   'IA_MAX_FIX_PUPIL_SIZE': nan,
#   'IA_MIN_FIX_PUPIL_SIZE': nan,
#   'Pupilsize_variation': nan,
#   'IA_FIRST_FIXATION_DURATION': nan,
#   'IA_SECOND_FIXATION_DURATION': nan,
#   'IA_SECOND_RUN_FIXATION_%': nan,
#   'IA_FIRST_RUN_FIXATION_%': nan,
#   'IA_REGRESSION_IN': 0,
#   'IA_RUN_COUNT': 0,
#   'IA_REGRESSION_IN_COUNT': 0,
#   'IA_REGRESSION_OUT': 0,
#   'IA_REGRESSION_OUT_COUNT': 0,
#   'backward_reg_count': 0,
#   'forward_reg_count': 0,
#   'total_reg_count': 0,
#   'backward_reg_list': [],
#   'forward_reg_list': [],
#   'total_reg_list': []},
#  ('p1', 44): {'IA_AVERAGE_FIX_PUPIL_SIZE': 848.5,
#   'IA_MAX_FIX_PUPIL_SIZE': 857.0,
#   'IA_MIN_FIX_PUPIL_SIZE': 840.0,
#   'Pupilsize_variation': 17.0,
#   'IA_FIRST_FIXATION_DURATION': 156.0,
#   'IA_SECOND_FIXATION_DURATION': 301.0,
#   'IA_SECOND_RUN_FIXATION_%': nan,
#   'IA_FIRST_RUN_FIXATION_%': 0.08,
#   'IA_REGRESSION_IN': 0,
#   'IA_RUN_COUNT': 0,
#   'IA_REGRESSION_IN_COUNT': 0,
#   'IA_REGRESSION_OUT': 0,
#   'IA_REGRESSION_OUT_COUNT': 0,
#   'backward_reg_count': 0,
#   'forward_reg_count': 0,
#   'total_reg_count': 0,
#   'backward_reg_list': [],
#   'forward_reg_list': [],
#   'total_reg_list': []},
#  ('p1', 45): {'IA_AVERAGE_FIX_PUPIL_SIZE': nan,
#   'IA_MAX_FIX_PUPIL_SIZE': nan,
#   'IA_MIN_FIX_PUPIL_SIZE': nan,
#   'Pupilsize_variation': nan,
#   'IA_FIRST_FIXATION_DURATION': nan,
#   'IA_SECOND_FIXATION_DURATION': nan,
#   'IA_SECOND_RUN_FIXATION_%': nan,
#   'IA_FIRST_RUN_FIXATION_%': nan,
#   'IA_REGRESSION_IN': 0,
#   'IA_RUN_COUNT': 0,
#   'IA_REGRESSION_IN_COUNT': 0,
#   'IA_REGRESSION_OUT': 0,
#   'IA_REGRESSION_OUT_COUNT': 0,
#   'backward_reg_count': 0,
#   'forward_reg_count': 0,
#   'total_reg_count': 0,
#   'backward_reg_list': [],
#   'forward_reg_list': [],
#   'total_reg_list': []},
#  ('p1', 46): {'IA_AVERAGE_FIX_PUPIL_SIZE': nan,
#   'IA_MAX_FIX_PUPIL_SIZE': nan,
#   'IA_MIN_FIX_PUPIL_SIZE': nan,
#   'Pupilsize_variation': nan,
#   'IA_FIRST_FIXATION_DURATION': nan,
#   'IA_SECOND_FIXATION_DURATION': nan,
#   'IA_SECOND_RUN_FIXATION_%': nan,
#   'IA_FIRST_RUN_FIXATION_%': nan,
#   'IA_REGRESSION_IN': 0,
#   'IA_RUN_COUNT': 0,
#   'IA_REGRESSION_IN_COUNT': 0,
#   'IA_REGRESSION_OUT': 0,
#   'IA_REGRESSION_OUT_COUNT': 0,
#   'backward_reg_count': 0,
#   'forward_reg_count': 0,
#   'total_reg_count': 0,
#   'backward_reg_list': [],
#   'forward_reg_list': [],
#   'total_reg_list': []},
#  ('p1', 47): {'IA_AVERAGE_FIX_PUPIL_SIZE': nan,
#   'IA_MAX_FIX_PUPIL_SIZE': nan,
#   'IA_MIN_FIX_PUPIL_SIZE': nan,
#   'Pupilsize_variation': nan,
#   'IA_FIRST_FIXATION_DURATION': nan,
#   'IA_SECOND_FIXATION_DURATION': nan,
#   'IA_SECOND_RUN_FIXATION_%': nan,
#   'IA_FIRST_RUN_FIXATION_%': nan,
#   'IA_REGRESSION_IN': 0,
#   'IA_RUN_COUNT': 0,
#   'IA_REGRESSION_IN_COUNT': 0,
#   'IA_REGRESSION_OUT': 0,
#   'IA_REGRESSION_OUT_COUNT': 0,
#   'backward_reg_count': 0,
#   'forward_reg_count': 0,
#   'total_reg_count': 0,
#   'backward_reg_list': [],
#   'forward_reg_list': [],
#   'total_reg_list': []},
#  ('p1', 48): {'IA_AVERAGE_FIX_PUPIL_SIZE': nan,
#   'IA_MAX_FIX_PUPIL_SIZE': nan,
#   'IA_MIN_FIX_PUPIL_SIZE': nan,
#   'Pupilsize_variation': nan,
#   'IA_FIRST_FIXATION_DURATION': nan,
#   'IA_SECOND_FIXATION_DURATION': nan,
#   'IA_SECOND_RUN_FIXATION_%': nan,
#   'IA_FIRST_RUN_FIXATION_%': nan,
#   'IA_REGRESSION_IN': 0,
#   'IA_RUN_COUNT': 0,
#   'IA_REGRESSION_IN_COUNT': 0,
#   'IA_REGRESSION_OUT': 0,
#   'IA_REGRESSION_OUT_COUNT': 0,
#   'backward_reg_count': 0,
#   'forward_reg_count': 0,
#   'total_reg_count': 0,
#   'backward_reg_list': [],
#   'forward_reg_list': [],
#   'total_reg_list': []},
#  ('p1', 49): {'IA_AVERAGE_FIX_PUPIL_SIZE': nan,
#   'IA_MAX_FIX_PUPIL_SIZE': nan,
#   'IA_MIN_FIX_PUPIL_SIZE': nan,
#   'Pupilsize_variation': nan,
#   'IA_FIRST_FIXATION_DURATION': nan,
#   'IA_SECOND_FIXATION_DURATION': nan,
#   'IA_SECOND_RUN_FIXATION_%': nan,
#   'IA_FIRST_RUN_FIXATION_%': nan,
#   'IA_REGRESSION_IN': 0,
#   'IA_RUN_COUNT': 0,
#   'IA_REGRESSION_IN_COUNT': 0,
#   'IA_REGRESSION_OUT': 0,
#   'IA_REGRESSION_OUT_COUNT': 0,
#   'backward_reg_count': 0,
#   'forward_reg_count': 0,
#   'total_reg_count': 0,
#   'backward_reg_list': [],
#   'forward_reg_list': [],
#   'total_reg_list': []},
#  ('p1', 50): {'IA_AVERAGE_FIX_PUPIL_SIZE': nan,
#   'IA_MAX_FIX_PUPIL_SIZE': nan,
#   'IA_MIN_FIX_PUPIL_SIZE': nan,
#   'Pupilsize_variation': nan,
#   'IA_FIRST_FIXATION_DURATION': nan,
#   'IA_SECOND_FIXATION_DURATION': nan,
#   'IA_SECOND_RUN_FIXATION_%': nan,
#   'IA_FIRST_RUN_FIXATION_%': nan,
#   'IA_REGRESSION_IN': 0,
#   'IA_RUN_COUNT': 0,
#   'IA_REGRESSION_IN_COUNT': 0,
#   'IA_REGRESSION_OUT': 0,
#   'IA_REGRESSION_OUT_COUNT': 0,
#   'backward_reg_count': 0,
#   'forward_reg_count': 0,
#   'total_reg_count': 0,
#   'backward_reg_list': [],
#   'forward_reg_list': [],
#   'total_reg_list': []},
#  ('p1', 51): {'IA_AVERAGE_FIX_PUPIL_SIZE': nan,
#   'IA_MAX_FIX_PUPIL_SIZE': nan,
#   'IA_MIN_FIX_PUPIL_SIZE': nan,
#   'Pupilsize_variation': nan,
#   'IA_FIRST_FIXATION_DURATION': nan,
#   'IA_SECOND_FIXATION_DURATION': nan,
#   'IA_SECOND_RUN_FIXATION_%': nan,
#   'IA_FIRST_RUN_FIXATION_%': nan,
#   'IA_REGRESSION_IN': 0,
#   'IA_RUN_COUNT': 0,
#   'IA_REGRESSION_IN_COUNT': 0,
#   'IA_REGRESSION_OUT': 0,
#   'IA_REGRESSION_OUT_COUNT': 0,
#   'backward_reg_count': 0,
#   'forward_reg_count': 0,
#   'total_reg_count': 0,
#   'backward_reg_list': [],
#   'forward_reg_list': [],
#   'total_reg_list': []},
#  ('p1', 52): {'IA_AVERAGE_FIX_PUPIL_SIZE': nan,
#   'IA_MAX_FIX_PUPIL_SIZE': nan,
#   'IA_MIN_FIX_PUPIL_SIZE': nan,
#   'Pupilsize_variation': nan,
#   'IA_FIRST_FIXATION_DURATION': nan,
#   'IA_SECOND_FIXATION_DURATION': nan,
#   'IA_SECOND_RUN_FIXATION_%': nan,
#   'IA_FIRST_RUN_FIXATION_%': nan,
#   'IA_REGRESSION_IN': 0,
#   'IA_RUN_COUNT': 0,
#   'IA_REGRESSION_IN_COUNT': 0,
#   'IA_REGRESSION_OUT': 0,
#   'IA_REGRESSION_OUT_COUNT': 0,
#   'backward_reg_count': 0,
#   'forward_reg_count': 0,
#   'total_reg_count': 0,
#   'backward_reg_list': [],
#   'forward_reg_list': [],
#   'total_reg_list': []},
#  ('p1', 53): {'IA_AVERAGE_FIX_PUPIL_SIZE': nan,
#   'IA_MAX_FIX_PUPIL_SIZE': nan,
#   'IA_MIN_FIX_PUPIL_SIZE': nan,
#   'Pupilsize_variation': nan,
#   'IA_FIRST_FIXATION_DURATION': nan,
#   'IA_SECOND_FIXATION_DURATION': nan,
#   'IA_SECOND_RUN_FIXATION_%': nan,
#   'IA_FIRST_RUN_FIXATION_%': nan,
#   'IA_REGRESSION_IN': 0,
#   'IA_RUN_COUNT': 0,
#   'IA_REGRESSION_IN_COUNT': 0,
#   'IA_REGRESSION_OUT': 0,
#   'IA_REGRESSION_OUT_COUNT': 0,
#   'backward_reg_count': 0,
#   'forward_reg_count': 0,
#   'total_reg_count': 0,
#   'backward_reg_list': [],
#   'forward_reg_list': [],
#   'total_reg_list': []},
#  ('p1', 54): {'IA_AVERAGE_FIX_PUPIL_SIZE': nan,
#   'IA_MAX_FIX_PUPIL_SIZE': nan,
#   'IA_MIN_FIX_PUPIL_SIZE': nan,
#   'Pupilsize_variation': nan,
#   'IA_FIRST_FIXATION_DURATION': nan,
#   'IA_SECOND_FIXATION_DURATION': nan,
#   'IA_SECOND_RUN_FIXATION_%': nan,
#   'IA_FIRST_RUN_FIXATION_%': nan,
#   'IA_REGRESSION_IN': 0,
#   'IA_RUN_COUNT': 0,
#   'IA_REGRESSION_IN_COUNT': 0,
#   'IA_REGRESSION_OUT': 0,
#   'IA_REGRESSION_OUT_COUNT': 0,
#   'backward_reg_count': 0,
#   'forward_reg_count': 0,
#   'total_reg_count': 0,
#   'backward_reg_list': [],
#   'forward_reg_list': [],
#   'total_reg_list': []},
#  ('p1', 55): {'IA_AVERAGE_FIX_PUPIL_SIZE': 864.6666666666666,
#   'IA_MAX_FIX_PUPIL_SIZE': 864.6666666666666,
#   'IA_MIN_FIX_PUPIL_SIZE': 864.6666666666666,
#   'Pupilsize_variation': 0.0,
#   'IA_FIRST_FIXATION_DURATION': 219.33333333333334,
#   'IA_SECOND_FIXATION_DURATION': nan,
#   'IA_SECOND_RUN_FIXATION_%': nan,
#   'IA_FIRST_RUN_FIXATION_%': 0.11110000000000002,
#   'IA_REGRESSION_IN': 0,
#   'IA_RUN_COUNT': 0,
#   'IA_REGRESSION_IN_COUNT': 0,
#   'IA_REGRESSION_OUT': 0,
#   'IA_REGRESSION_OUT_COUNT': 0,
#   'backward_reg_count': 0,
#   'forward_reg_count': 0,
#   'total_reg_count': 0,
#   'backward_reg_list': [],
#   'forward_reg_list': [],
#   'total_reg_list': []},
#  ('p1', 56): {'IA_AVERAGE_FIX_PUPIL_SIZE': nan,
#   'IA_MAX_FIX_PUPIL_SIZE': nan,
#   'IA_MIN_FIX_PUPIL_SIZE': nan,
#   'Pupilsize_variation': nan,
#   'IA_FIRST_FIXATION_DURATION': nan,
#   'IA_SECOND_FIXATION_DURATION': nan,
#   'IA_SECOND_RUN_FIXATION_%': nan,
#   'IA_FIRST_RUN_FIXATION_%': nan,
#   'IA_REGRESSION_IN': 0,
#   'IA_RUN_COUNT': 0,
#   'IA_REGRESSION_IN_COUNT': 0,
#   'IA_REGRESSION_OUT': 0,
#   'IA_REGRESSION_OUT_COUNT': 0,
#   'backward_reg_count': 0,
#   'forward_reg_count': 0,
#   'total_reg_count': 0,
#   'backward_reg_list': [],
#   'forward_reg_list': [],
#   'total_reg_list': []},
#  ('p1', 57): {'IA_AVERAGE_FIX_PUPIL_SIZE': nan,
#   'IA_MAX_FIX_PUPIL_SIZE': nan,
#   'IA_MIN_FIX_PUPIL_SIZE': nan,
#   'Pupilsize_variation': nan,
#   'IA_FIRST_FIXATION_DURATION': nan,
#   'IA_SECOND_FIXATION_DURATION': nan,
#   'IA_SECOND_RUN_FIXATION_%': nan,
#   'IA_FIRST_RUN_FIXATION_%': nan,
#   'IA_REGRESSION_IN': 0,
#   'IA_RUN_COUNT': 0,
#   'IA_REGRESSION_IN_COUNT': 0,
#   'IA_REGRESSION_OUT': 0,
#   'IA_REGRESSION_OUT_COUNT': 0,
#   'backward_reg_count': 0,
#   'forward_reg_count': 0,
#   'total_reg_count': 0,
#   'backward_reg_list': [],
#   'forward_reg_list': [],
#   'total_reg_list': []},
#  ('p1', 58): {'IA_AVERAGE_FIX_PUPIL_SIZE': 816.0,
#   'IA_MAX_FIX_PUPIL_SIZE': 816.0,
#   'IA_MIN_FIX_PUPIL_SIZE': 816.0,
#   'Pupilsize_variation': 0.0,
#   'IA_FIRST_FIXATION_DURATION': 151.0,
#   'IA_SECOND_FIXATION_DURATION': nan,
#   'IA_SECOND_RUN_FIXATION_%': nan,
#   'IA_FIRST_RUN_FIXATION_%': 0.027,
#   'IA_REGRESSION_IN': 0,
#   'IA_RUN_COUNT': 0,
#   'IA_REGRESSION_IN_COUNT': 0,
#   'IA_REGRESSION_OUT': 0,
#   'IA_REGRESSION_OUT_COUNT': 0,
#   'backward_reg_count': 0,
#   'forward_reg_count': 0,
#   'total_reg_count': 0,
#   'backward_reg_list': [],
#   'forward_reg_list': [],
#   'total_reg_list': []},
#  ('p1', 59): {'IA_AVERAGE_FIX_PUPIL_SIZE': nan,
#   'IA_MAX_FIX_PUPIL_SIZE': nan,
#   'IA_MIN_FIX_PUPIL_SIZE': nan,
#   'Pupilsize_variation': nan,
#   'IA_FIRST_FIXATION_DURATION': nan,
#   'IA_SECOND_FIXATION_DURATION': nan,
#   'IA_SECOND_RUN_FIXATION_%': nan,
#   'IA_FIRST_RUN_FIXATION_%': nan,
#   'IA_REGRESSION_IN': 0,
#   'IA_RUN_COUNT': 0,
#   'IA_REGRESSION_IN_COUNT': 0,
#   'IA_REGRESSION_OUT': 0,
#   'IA_REGRESSION_OUT_COUNT': 0,
#   'backward_reg_count': 0,
#   'forward_reg_count': 0,
#   'total_reg_count': 0,
#   'backward_reg_list': [],
#   'forward_reg_list': [],
#   'total_reg_list': []},
#  ('p1', 60): {'IA_AVERAGE_FIX_PUPIL_SIZE': nan,
#   'IA_MAX_FIX_PUPIL_SIZE': nan,
#   'IA_MIN_FIX_PUPIL_SIZE': nan,
#   'Pupilsize_variation': nan,
#   'IA_FIRST_FIXATION_DURATION': nan,
#   'IA_SECOND_FIXATION_DURATION': nan,
#   'IA_SECOND_RUN_FIXATION_%': nan,
#   'IA_FIRST_RUN_FIXATION_%': nan,
#   'IA_REGRESSION_IN': 0,
#   'IA_RUN_COUNT': 0,
#   'IA_REGRESSION_IN_COUNT': 0,
#   'IA_REGRESSION_OUT': 0,
#   'IA_REGRESSION_OUT_COUNT': 0,
#   'backward_reg_count': 0,
#   'forward_reg_count': 0,
#   'total_reg_count': 0,
#   'backward_reg_list': [],
#   'forward_reg_list': [],
#   'total_reg_list': []},
#  ('p1', 61): {'IA_AVERAGE_FIX_PUPIL_SIZE': nan,
#   'IA_MAX_FIX_PUPIL_SIZE': nan,
#   'IA_MIN_FIX_PUPIL_SIZE': nan,
#   'Pupilsize_variation': nan,
#   'IA_FIRST_FIXATION_DURATION': nan,
#   'IA_SECOND_FIXATION_DURATION': nan,
#   'IA_SECOND_RUN_FIXATION_%': nan,
#   'IA_FIRST_RUN_FIXATION_%': nan,
#   'IA_REGRESSION_IN': 0,
#   'IA_RUN_COUNT': 0,
#   'IA_REGRESSION_IN_COUNT': 0,
#   'IA_REGRESSION_OUT': 0,
#   'IA_REGRESSION_OUT_COUNT': 0,
#   'backward_reg_count': 0,
#   'forward_reg_count': 0,
#   'total_reg_count': 0,
#   'backward_reg_list': [],
#   'forward_reg_list': [],
#   'total_reg_list': []},
#  ('p1', 62): {'IA_AVERAGE_FIX_PUPIL_SIZE': nan,
#   'IA_MAX_FIX_PUPIL_SIZE': nan,
#   'IA_MIN_FIX_PUPIL_SIZE': nan,
#   'Pupilsize_variation': nan,
#   'IA_FIRST_FIXATION_DURATION': nan,
#   'IA_SECOND_FIXATION_DURATION': nan,
#   'IA_SECOND_RUN_FIXATION_%': nan,
#   'IA_FIRST_RUN_FIXATION_%': nan,
#   'IA_REGRESSION_IN': 0,
#   'IA_RUN_COUNT': 0,
#   'IA_REGRESSION_IN_COUNT': 0,
#   'IA_REGRESSION_OUT': 0,
#   'IA_REGRESSION_OUT_COUNT': 0,
#   'backward_reg_count': 0,
#   'forward_reg_count': 0,
#   'total_reg_count': 0,
#   'backward_reg_list': [],
#   'forward_reg_list': [],
#   'total_reg_list': []},
#  ('p1', 63): {'IA_AVERAGE_FIX_PUPIL_SIZE': nan,
#   'IA_MAX_FIX_PUPIL_SIZE': nan,
#   'IA_MIN_FIX_PUPIL_SIZE': nan,
#   'Pupilsize_variation': nan,
#   'IA_FIRST_FIXATION_DURATION': nan,
#   'IA_SECOND_FIXATION_DURATION': nan,
#   'IA_SECOND_RUN_FIXATION_%': nan,
#   'IA_FIRST_RUN_FIXATION_%': nan,
#   'IA_REGRESSION_IN': 0,
#   'IA_RUN_COUNT': 0,
#   'IA_REGRESSION_IN_COUNT': 0,
#   'IA_REGRESSION_OUT': 0,
#   'IA_REGRESSION_OUT_COUNT': 0,
#   'backward_reg_count': 0,
#   'forward_reg_count': 0,
#   'total_reg_count': 0,
#   'backward_reg_list': [],
#   'forward_reg_list': [],
#   'total_reg_list': []},
#  ('p1', 64): {'IA_AVERAGE_FIX_PUPIL_SIZE': 900.6666666666666,
#   'IA_MAX_FIX_PUPIL_SIZE': 908.0,
#   'IA_MIN_FIX_PUPIL_SIZE': 893.3333333333334,
#   'Pupilsize_variation': 14.666666666666666,
#   'IA_FIRST_FIXATION_DURATION': 138.66666666666666,
#   'IA_SECOND_FIXATION_DURATION': 214.5,
#   'IA_SECOND_RUN_FIXATION_%': 0.0625,
#   'IA_FIRST_RUN_FIXATION_%': 0.0625,
#   'IA_REGRESSION_IN': 0,
#   'IA_RUN_COUNT': 0,
#   'IA_REGRESSION_IN_COUNT': 0,
#   'IA_REGRESSION_OUT': 0,
#   'IA_REGRESSION_OUT_COUNT': 0,
#   'backward_reg_count': 0,
#   'forward_reg_count': 0,
#   'total_reg_count': 0,
#   'backward_reg_list': [],
#   'forward_reg_list': [],
#   'total_reg_list': []},
#  ('p1', 65): {'IA_AVERAGE_FIX_PUPIL_SIZE': nan,
#   'IA_MAX_FIX_PUPIL_SIZE': nan,
#   'IA_MIN_FIX_PUPIL_SIZE': nan,
#   'Pupilsize_variation': nan,
#   'IA_FIRST_FIXATION_DURATION': nan,
#   'IA_SECOND_FIXATION_DURATION': nan,
#   'IA_SECOND_RUN_FIXATION_%': nan,
#   'IA_FIRST_RUN_FIXATION_%': nan,
#   'IA_REGRESSION_IN': 0,
#   'IA_RUN_COUNT': 0,
#   'IA_REGRESSION_IN_COUNT': 0,
#   'IA_REGRESSION_OUT': 0,
#   'IA_REGRESSION_OUT_COUNT': 0,
#   'backward_reg_count': 0,
#   'forward_reg_count': 0,
#   'total_reg_count': 0,
#   'backward_reg_list': [],
#   'forward_reg_list': [],
#   'total_reg_list': []},
#  ('p1', 66): {'IA_AVERAGE_FIX_PUPIL_SIZE': nan,
#   'IA_MAX_FIX_PUPIL_SIZE': nan,
#   'IA_MIN_FIX_PUPIL_SIZE': nan,
#   'Pupilsize_variation': nan,
#   'IA_FIRST_FIXATION_DURATION': nan,
#   'IA_SECOND_FIXATION_DURATION': nan,
#   'IA_SECOND_RUN_FIXATION_%': nan,
#   'IA_FIRST_RUN_FIXATION_%': nan,
#   'IA_REGRESSION_IN': 0,
#   'IA_RUN_COUNT': 0,
#   'IA_REGRESSION_IN_COUNT': 0,
#   'IA_REGRESSION_OUT': 0,
#   'IA_REGRESSION_OUT_COUNT': 0,
#   'backward_reg_count': 0,
#   'forward_reg_count': 0,
#   'total_reg_count': 0,
#   'backward_reg_list': [],
#   'forward_reg_list': [],
#   'total_reg_list': []},
#  ('p1', 67): {'IA_AVERAGE_FIX_PUPIL_SIZE': nan,
#   'IA_MAX_FIX_PUPIL_SIZE': nan,
#   'IA_MIN_FIX_PUPIL_SIZE': nan,
#   'Pupilsize_variation': nan,
#   'IA_FIRST_FIXATION_DURATION': nan,
#   'IA_SECOND_FIXATION_DURATION': nan,
#   'IA_SECOND_RUN_FIXATION_%': nan,
#   'IA_FIRST_RUN_FIXATION_%': nan,
#   'IA_REGRESSION_IN': 0,
#   'IA_RUN_COUNT': 0,
#   'IA_REGRESSION_IN_COUNT': 0,
#   'IA_REGRESSION_OUT': 0,
#   'IA_REGRESSION_OUT_COUNT': 0,
#   'backward_reg_count': 0,
#   'forward_reg_count': 0,
#   'total_reg_count': 0,
#   'backward_reg_list': [],
#   'forward_reg_list': [],
#   'total_reg_list': []},
#  ('p1', 68): {'IA_AVERAGE_FIX_PUPIL_SIZE': 789.0,
#   'IA_MAX_FIX_PUPIL_SIZE': 789.0,
#   'IA_MIN_FIX_PUPIL_SIZE': 789.0,
#   'Pupilsize_variation': 0.0,
#   'IA_FIRST_FIXATION_DURATION': 124.0,
#   'IA_SECOND_FIXATION_DURATION': nan,
#   'IA_SECOND_RUN_FIXATION_%': nan,
#   'IA_FIRST_RUN_FIXATION_%': 0.0213,
#   'IA_REGRESSION_IN': 0,
#   'IA_RUN_COUNT': 0,
#   'IA_REGRESSION_IN_COUNT': 0,
#   'IA_REGRESSION_OUT': 0,
#   'IA_REGRESSION_OUT_COUNT': 0,
#   'backward_reg_count': 0,
#   'forward_reg_count': 0,
#   'total_reg_count': 0,
#   'backward_reg_list': [],
#   'forward_reg_list': [],
#   'total_reg_list': []},
#  ('p1', 69): {'IA_AVERAGE_FIX_PUPIL_SIZE': nan,
#   'IA_MAX_FIX_PUPIL_SIZE': nan,
#   'IA_MIN_FIX_PUPIL_SIZE': nan,
#   'Pupilsize_variation': nan,
#   'IA_FIRST_FIXATION_DURATION': nan,
#   'IA_SECOND_FIXATION_DURATION': nan,
#   'IA_SECOND_RUN_FIXATION_%': nan,
#   'IA_FIRST_RUN_FIXATION_%': nan,
#   'IA_REGRESSION_IN': 0,
#   'IA_RUN_COUNT': 0,
#   'IA_REGRESSION_IN_COUNT': 0,
#   'IA_REGRESSION_OUT': 0,
#   'IA_REGRESSION_OUT_COUNT': 0,
#   'backward_reg_count': 0,
#   'forward_reg_count': 0,
#   'total_reg_count': 0,
#   'backward_reg_list': [],
#   'forward_reg_list': [],
#   'total_reg_list': []},
#  ('p1', 70): {'IA_AVERAGE_FIX_PUPIL_SIZE': nan,
#   'IA_MAX_FIX_PUPIL_SIZE': nan,
#   'IA_MIN_FIX_PUPIL_SIZE': nan,
#   'Pupilsize_variation': nan,
#   'IA_FIRST_FIXATION_DURATION': nan,
#   'IA_SECOND_FIXATION_DURATION': nan,
#   'IA_SECOND_RUN_FIXATION_%': nan,
#   'IA_FIRST_RUN_FIXATION_%': nan,
#   'IA_REGRESSION_IN': 0,
#   'IA_RUN_COUNT': 0,
#   'IA_REGRESSION_IN_COUNT': 0,
#   'IA_REGRESSION_OUT': 0,
#   'IA_REGRESSION_OUT_COUNT': 0,
#   'backward_reg_count': 0,
#   'forward_reg_count': 0,
#   'total_reg_count': 0,
#   'backward_reg_list': [],
#   'forward_reg_list': [],
#   'total_reg_list': []},
#  ('p1', 71): {'IA_AVERAGE_FIX_PUPIL_SIZE': nan,
#   'IA_MAX_FIX_PUPIL_SIZE': nan,
#   'IA_MIN_FIX_PUPIL_SIZE': nan,
#   'Pupilsize_variation': nan,
#   'IA_FIRST_FIXATION_DURATION': nan,
#   'IA_SECOND_FIXATION_DURATION': nan,
#   'IA_SECOND_RUN_FIXATION_%': nan,
#   'IA_FIRST_RUN_FIXATION_%': nan,
#   'IA_REGRESSION_IN': 0,
#   'IA_RUN_COUNT': 0,
#   'IA_REGRESSION_IN_COUNT': 0,
#   'IA_REGRESSION_OUT': 0,
#   'IA_REGRESSION_OUT_COUNT': 0,
#   'backward_reg_count': 0,
#   'forward_reg_count': 0,
#   'total_reg_count': 0,
#   'backward_reg_list': [],
#   'forward_reg_list': [],
#   'total_reg_list': []},
#  ('p1', 72): {'IA_AVERAGE_FIX_PUPIL_SIZE': nan,
#   'IA_MAX_FIX_PUPIL_SIZE': nan,
#   'IA_MIN_FIX_PUPIL_SIZE': nan,
#   'Pupilsize_variation': nan,
#   'IA_FIRST_FIXATION_DURATION': nan,
#   'IA_SECOND_FIXATION_DURATION': nan,
#   'IA_SECOND_RUN_FIXATION_%': nan,
#   'IA_FIRST_RUN_FIXATION_%': nan,
#   'IA_REGRESSION_IN': 0,
#   'IA_RUN_COUNT': 0,
#   'IA_REGRESSION_IN_COUNT': 0,
#   'IA_REGRESSION_OUT': 0,
#   'IA_REGRESSION_OUT_COUNT': 0,
#   'backward_reg_count': 0,
#   'forward_reg_count': 0,
#   'total_reg_count': 0,
#   'backward_reg_list': [],
#   'forward_reg_list': [],
#   'total_reg_list': []},
#  ('p1', 73): {'IA_AVERAGE_FIX_PUPIL_SIZE': nan,
#   'IA_MAX_FIX_PUPIL_SIZE': nan,
#   'IA_MIN_FIX_PUPIL_SIZE': nan,
#   'Pupilsize_variation': nan,
#   'IA_FIRST_FIXATION_DURATION': nan,
#   'IA_SECOND_FIXATION_DURATION': nan,
#   'IA_SECOND_RUN_FIXATION_%': nan,
#   'IA_FIRST_RUN_FIXATION_%': nan,
#   'IA_REGRESSION_IN': 0,
#   'IA_RUN_COUNT': 0,
#   'IA_REGRESSION_IN_COUNT': 0,
#   'IA_REGRESSION_OUT': 0,
#   'IA_REGRESSION_OUT_COUNT': 0,
#   'backward_reg_count': 0,
#   'forward_reg_count': 0,
#   'total_reg_count': 0,
#   'backward_reg_list': [],
#   'forward_reg_list': [],
#   'total_reg_list': []},
#  ('p1', 74): {'IA_AVERAGE_FIX_PUPIL_SIZE': nan,
#   'IA_MAX_FIX_PUPIL_SIZE': nan,
#   'IA_MIN_FIX_PUPIL_SIZE': nan,
#   'Pupilsize_variation': nan,
#   'IA_FIRST_FIXATION_DURATION': nan,
#   'IA_SECOND_FIXATION_DURATION': nan,
#   'IA_SECOND_RUN_FIXATION_%': nan,
#   'IA_FIRST_RUN_FIXATION_%': nan,
#   'IA_REGRESSION_IN': 0,
#   'IA_RUN_COUNT': 0,
#   'IA_REGRESSION_IN_COUNT': 0,
#   'IA_REGRESSION_OUT': 0,
#   'IA_REGRESSION_OUT_COUNT': 0,
#   'backward_reg_count': 0,
#   'forward_reg_count': 0,
#   'total_reg_count': 0,
#   'backward_reg_list': [],
#   'forward_reg_list': [],
#   'total_reg_list': []},
#  ('p1', 75): {'IA_AVERAGE_FIX_PUPIL_SIZE': nan,
#   'IA_MAX_FIX_PUPIL_SIZE': nan,
#   'IA_MIN_FIX_PUPIL_SIZE': nan,
#   'Pupilsize_variation': nan,
#   'IA_FIRST_FIXATION_DURATION': nan,
#   'IA_SECOND_FIXATION_DURATION': nan,
#   'IA_SECOND_RUN_FIXATION_%': nan,
#   'IA_FIRST_RUN_FIXATION_%': nan,
#   'IA_REGRESSION_IN': 0,
#   'IA_RUN_COUNT': 0,
#   'IA_REGRESSION_IN_COUNT': 0,
#   'IA_REGRESSION_OUT': 0,
#   'IA_REGRESSION_OUT_COUNT': 0,
#   'backward_reg_count': 0,
#   'forward_reg_count': 0,
#   'total_reg_count': 0,
#   'backward_reg_list': [],
#   'forward_reg_list': [],
#   'total_reg_list': []},
#  ('p1', 76): {'IA_AVERAGE_FIX_PUPIL_SIZE': nan,
#   'IA_MAX_FIX_PUPIL_SIZE': nan,
#   'IA_MIN_FIX_PUPIL_SIZE': nan,
#   'Pupilsize_variation': nan,
#   'IA_FIRST_FIXATION_DURATION': nan,
#   'IA_SECOND_FIXATION_DURATION': nan,
#   'IA_SECOND_RUN_FIXATION_%': nan,
#   'IA_FIRST_RUN_FIXATION_%': nan,
#   'IA_REGRESSION_IN': 0,
#   'IA_RUN_COUNT': 0,
#   'IA_REGRESSION_IN_COUNT': 0,
#   'IA_REGRESSION_OUT': 0,
#   'IA_REGRESSION_OUT_COUNT': 0,
#   'backward_reg_count': 0,
#   'forward_reg_count': 0,
#   'total_reg_count': 0,
#   'backward_reg_list': [],
#   'forward_reg_list': [],
#   'total_reg_list': []},
#  ('p1', 77): {'IA_AVERAGE_FIX_PUPIL_SIZE': nan,
#   'IA_MAX_FIX_PUPIL_SIZE': nan,
#   'IA_MIN_FIX_PUPIL_SIZE': nan,
#   'Pupilsize_variation': nan,
#   'IA_FIRST_FIXATION_DURATION': nan,
#   'IA_SECOND_FIXATION_DURATION': nan,
#   'IA_SECOND_RUN_FIXATION_%': nan,
#   'IA_FIRST_RUN_FIXATION_%': nan,
#   'IA_REGRESSION_IN': 0,
#   'IA_RUN_COUNT': 0,
#   'IA_REGRESSION_IN_COUNT': 0,
#   'IA_REGRESSION_OUT': 0,
#   'IA_REGRESSION_OUT_COUNT': 0,
#   'backward_reg_count': 0,
#   'forward_reg_count': 0,
#   'total_reg_count': 0,
#   'backward_reg_list': [],
#   'forward_reg_list': [],
#   'total_reg_list': []},
#  ('p1', 78): {'IA_AVERAGE_FIX_PUPIL_SIZE': nan,
#   'IA_MAX_FIX_PUPIL_SIZE': nan,
#   'IA_MIN_FIX_PUPIL_SIZE': nan,
#   'Pupilsize_variation': nan,
#   'IA_FIRST_FIXATION_DURATION': nan,
#   'IA_SECOND_FIXATION_DURATION': nan,
#   'IA_SECOND_RUN_FIXATION_%': nan,
#   'IA_FIRST_RUN_FIXATION_%': nan,
#   'IA_REGRESSION_IN': 0,
#   'IA_RUN_COUNT': 0,
#   'IA_REGRESSION_IN_COUNT': 0,
#   'IA_REGRESSION_OUT': 0,
#   'IA_REGRESSION_OUT_COUNT': 0,
#   'backward_reg_count': 0,
#   'forward_reg_count': 0,
#   'total_reg_count': 0,
#   'backward_reg_list': [],
#   'forward_reg_list': [],
#   'total_reg_list': []},
#  ('p1', 79): {'IA_AVERAGE_FIX_PUPIL_SIZE': nan,
#   'IA_MAX_FIX_PUPIL_SIZE': nan,
#   'IA_MIN_FIX_PUPIL_SIZE': nan,
#   'Pupilsize_variation': nan,
#   'IA_FIRST_FIXATION_DURATION': nan,
#   'IA_SECOND_FIXATION_DURATION': nan,
#   'IA_SECOND_RUN_FIXATION_%': nan,
#   'IA_FIRST_RUN_FIXATION_%': nan,
#   'IA_REGRESSION_IN': 0,
#   'IA_RUN_COUNT': 0,
#   'IA_REGRESSION_IN_COUNT': 0,
#   'IA_REGRESSION_OUT': 0,
#   'IA_REGRESSION_OUT_COUNT': 0,
#   'backward_reg_count': 0,
#   'forward_reg_count': 0,
#   'total_reg_count': 0,
#   'backward_reg_list': [],
#   'forward_reg_list': [],
#   'total_reg_list': []},
#  ('p1', 80): {'IA_AVERAGE_FIX_PUPIL_SIZE': 960.0,
#   'IA_MAX_FIX_PUPIL_SIZE': 960.0,
#   'IA_MIN_FIX_PUPIL_SIZE': 960.0,
#   'Pupilsize_variation': 0.0,
#   'IA_FIRST_FIXATION_DURATION': 170.0,
#   'IA_SECOND_FIXATION_DURATION': nan,
#   'IA_SECOND_RUN_FIXATION_%': nan,
#   'IA_FIRST_RUN_FIXATION_%': 0.0833,
#   'IA_REGRESSION_IN': 0,
#   'IA_RUN_COUNT': 0,
#   'IA_REGRESSION_IN_COUNT': 0,
#   'IA_REGRESSION_OUT': 0,
#   'IA_REGRESSION_OUT_COUNT': 0,
#   'backward_reg_count': 0,
#   'forward_reg_count': 0,
#   'total_reg_count': 0,
#   'backward_reg_list': [],
#   'forward_reg_list': [],
#   'total_reg_list': []},
#  ('p1', 81): {'IA_AVERAGE_FIX_PUPIL_SIZE': nan,
#   'IA_MAX_FIX_PUPIL_SIZE': nan,
#   'IA_MIN_FIX_PUPIL_SIZE': nan,
#   'Pupilsize_variation': nan,
#   'IA_FIRST_FIXATION_DURATION': nan,
#   'IA_SECOND_FIXATION_DURATION': nan,
#   'IA_SECOND_RUN_FIXATION_%': nan,
#   'IA_FIRST_RUN_FIXATION_%': nan,
#   'IA_REGRESSION_IN': 0,
#   'IA_RUN_COUNT': 0,
#   'IA_REGRESSION_IN_COUNT': 0,
#   'IA_REGRESSION_OUT': 0,
#   'IA_REGRESSION_OUT_COUNT': 0,
#   'backward_reg_count': 0,
#   'forward_reg_count': 0,
#   'total_reg_count': 0,
#   'backward_reg_list': [],
#   'forward_reg_list': [],
#   'total_reg_list': []},
#  ('p1', 82): {'IA_AVERAGE_FIX_PUPIL_SIZE': nan,
#   'IA_MAX_FIX_PUPIL_SIZE': nan,
#   'IA_MIN_FIX_PUPIL_SIZE': nan,
#   'Pupilsize_variation': nan,
#   'IA_FIRST_FIXATION_DURATION': nan,
#   'IA_SECOND_FIXATION_DURATION': nan,
#   'IA_SECOND_RUN_FIXATION_%': nan,
#   'IA_FIRST_RUN_FIXATION_%': nan,
#   'IA_REGRESSION_IN': 0,
#   'IA_RUN_COUNT': 0,
#   'IA_REGRESSION_IN_COUNT': 0,
#   'IA_REGRESSION_OUT': 0,
#   'IA_REGRESSION_OUT_COUNT': 0,
#   'backward_reg_count': 0,
#   'forward_reg_count': 0,
#   'total_reg_count': 0,
#   'backward_reg_list': [],
#   'forward_reg_list': [],
#   'total_reg_list': []},
#  ('p1', 83): {'IA_AVERAGE_FIX_PUPIL_SIZE': nan,
#   'IA_MAX_FIX_PUPIL_SIZE': nan,
#   'IA_MIN_FIX_PUPIL_SIZE': nan,
#   'Pupilsize_variation': nan,
#   'IA_FIRST_FIXATION_DURATION': nan,
#   'IA_SECOND_FIXATION_DURATION': nan,
#   'IA_SECOND_RUN_FIXATION_%': nan,
#   'IA_FIRST_RUN_FIXATION_%': nan,
#   'IA_REGRESSION_IN': 0,
#   'IA_RUN_COUNT': 0,
#   'IA_REGRESSION_IN_COUNT': 0,
#   'IA_REGRESSION_OUT': 0,
#   'IA_REGRESSION_OUT_COUNT': 0,
#   'backward_reg_count': 0,
#   'forward_reg_count': 0,
#   'total_reg_count': 0,
#   'backward_reg_list': [],
#   'forward_reg_list': [],
#   'total_reg_list': []},
#  ('p1', 84): {'IA_AVERAGE_FIX_PUPIL_SIZE': nan,
#   'IA_MAX_FIX_PUPIL_SIZE': nan,
#   'IA_MIN_FIX_PUPIL_SIZE': nan,
#   'Pupilsize_variation': nan,
#   'IA_FIRST_FIXATION_DURATION': nan,
#   'IA_SECOND_FIXATION_DURATION': nan,
#   'IA_SECOND_RUN_FIXATION_%': nan,
#   'IA_FIRST_RUN_FIXATION_%': nan,
#   'IA_REGRESSION_IN': 0,
#   'IA_RUN_COUNT': 0,
#   'IA_REGRESSION_IN_COUNT': 0,
#   'IA_REGRESSION_OUT': 0,
#   'IA_REGRESSION_OUT_COUNT': 0,
#   'backward_reg_count': 0,
#   'forward_reg_count': 0,
#   'total_reg_count': 0,
#   'backward_reg_list': [],
#   'forward_reg_list': [],
#   'total_reg_list': []},
#  ('p1', 85): {'IA_AVERAGE_FIX_PUPIL_SIZE': nan,
#   'IA_MAX_FIX_PUPIL_SIZE': nan,
#   'IA_MIN_FIX_PUPIL_SIZE': nan,
#   'Pupilsize_variation': nan,
#   'IA_FIRST_FIXATION_DURATION': nan,
# ...
#   'Pupilsize_variation': 51.833333333333336,
#   'IA_FIRST_FIXATION_DURATION': 250.16666666666666,
#   'IA_SECOND_FIXATION_DURATION': 152.0,
#   'IA_SECOND_RUN_FIXATION_%': 0.1389,
#   'IA_FIRST_RUN_FIXATION_%': 0.09261666666666667,
#   'IA_REGRESSION_IN': 0,
#   'IA_RUN_COUNT': 0,
#   'IA_REGRESSION_IN_COUNT': 0,
#   'IA_REGRESSION_OUT': 0,
#   'IA_REGRESSION_OUT_COUNT': 0,
#   'backward_reg_count': 0,
#   'forward_reg_count': 0,
#   'total_reg_count': 0,
#   'backward_reg_list': [],
#   'forward_reg_list': [],
#   'total_reg_list': []},
#  ('p2', 81): {'IA_AVERAGE_FIX_PUPIL_SIZE': 1302.7,
#   'IA_MAX_FIX_PUPIL_SIZE': 1311.8,
#   'IA_MIN_FIX_PUPIL_SIZE': 1296.6,
#   'Pupilsize_variation': 15.2,
#   'IA_FIRST_FIXATION_DURATION': 177.8,
#   'IA_SECOND_FIXATION_DURATION': 299.0,
#   'IA_SECOND_RUN_FIXATION_%': nan,
#   'IA_FIRST_RUN_FIXATION_%': 0.18181999999999998,
#   'IA_REGRESSION_IN': 0,
#   'IA_RUN_COUNT': 0,
#   'IA_REGRESSION_IN_COUNT': 0,
#   'IA_REGRESSION_OUT': 0,
#   'IA_REGRESSION_OUT_COUNT': 0,
#   'backward_reg_count': 0,
#   'forward_reg_count': 0,
#   'total_reg_count': 0,
#   'backward_reg_list': [],
#   'forward_reg_list': [],
#   'total_reg_list': []},
#  ('p2', 82): {'IA_AVERAGE_FIX_PUPIL_SIZE': 1270.21875,
#   'IA_MAX_FIX_PUPIL_SIZE': 1278.75,
#   'IA_MIN_FIX_PUPIL_SIZE': 1261.875,
#   'Pupilsize_variation': 16.875,
#   'IA_FIRST_FIXATION_DURATION': 126.5,
#   'IA_SECOND_FIXATION_DURATION': 219.0,
#   'IA_SECOND_RUN_FIXATION_%': 0.0476,
#   'IA_FIRST_RUN_FIXATION_%': 0.07141249999999999,
#   'IA_REGRESSION_IN': 0,
#   'IA_RUN_COUNT': 0,
#   'IA_REGRESSION_IN_COUNT': 0,
#   'IA_REGRESSION_OUT': 0,
#   'IA_REGRESSION_OUT_COUNT': 0,
#   'backward_reg_count': 0,
#   'forward_reg_count': 0,
#   'total_reg_count': 0,
#   'backward_reg_list': [],
#   'forward_reg_list': [],
#   'total_reg_list': []},
#  ('p2', 83): {'IA_AVERAGE_FIX_PUPIL_SIZE': 1332.9716666666666,
#   'IA_MAX_FIX_PUPIL_SIZE': 1347.0,
#   'IA_MIN_FIX_PUPIL_SIZE': 1310.8333333333333,
#   'Pupilsize_variation': 36.166666666666664,
#   'IA_FIRST_FIXATION_DURATION': 236.66666666666666,
#   'IA_SECOND_FIXATION_DURATION': 270.3333333333333,
#   'IA_SECOND_RUN_FIXATION_%': 0.0769,
#   'IA_FIRST_RUN_FIXATION_%': 0.10253333333333332,
#   'IA_REGRESSION_IN': 0,
#   'IA_RUN_COUNT': 0,
#   'IA_REGRESSION_IN_COUNT': 0,
#   'IA_REGRESSION_OUT': 0,
#   'IA_REGRESSION_OUT_COUNT': 0,
#   'backward_reg_count': 0,
#   'forward_reg_count': 0,
#   'total_reg_count': 0,
#   'backward_reg_list': [],
#   'forward_reg_list': [],
#   'total_reg_list': []},
#  ('p2', 84): {'IA_AVERAGE_FIX_PUPIL_SIZE': 1383.3883333333333,
#   'IA_MAX_FIX_PUPIL_SIZE': 1391.1666666666667,
#   'IA_MIN_FIX_PUPIL_SIZE': 1375.5,
#   'Pupilsize_variation': 15.666666666666666,
#   'IA_FIRST_FIXATION_DURATION': 210.66666666666666,
#   'IA_SECOND_FIXATION_DURATION': 308.5,
#   'IA_SECOND_RUN_FIXATION_%': 0.0769,
#   'IA_FIRST_RUN_FIXATION_%': 0.08971666666666667,
#   'IA_REGRESSION_IN': 0,
#   'IA_RUN_COUNT': 0,
#   'IA_REGRESSION_IN_COUNT': 0,
#   'IA_REGRESSION_OUT': 0,
#   'IA_REGRESSION_OUT_COUNT': 0,
#   'backward_reg_count': 0,
#   'forward_reg_count': 0,
#   'total_reg_count': 0,
#   'backward_reg_list': [],
#   'forward_reg_list': [],
#   'total_reg_list': []},
#  ('p2', 85): {'IA_AVERAGE_FIX_PUPIL_SIZE': 1430.0,
#   'IA_MAX_FIX_PUPIL_SIZE': 1447.0,
#   'IA_MIN_FIX_PUPIL_SIZE': 1413.3333333333333,
#   'Pupilsize_variation': 33.666666666666664,
#   'IA_FIRST_FIXATION_DURATION': 208.66666666666666,
#   'IA_SECOND_FIXATION_DURATION': 183.0,
#   'IA_SECOND_RUN_FIXATION_%': 0.1429,
#   'IA_FIRST_RUN_FIXATION_%': 0.2381333333333333,
#   'IA_REGRESSION_IN': 0,
#   'IA_RUN_COUNT': 0,
#   'IA_REGRESSION_IN_COUNT': 0,
#   'IA_REGRESSION_OUT': 0,
#   'IA_REGRESSION_OUT_COUNT': 0,
#   'backward_reg_count': 0,
#   'forward_reg_count': 0,
#   'total_reg_count': 0,
#   'backward_reg_list': [],
#   'forward_reg_list': [],
#   'total_reg_list': []},
#  ('p2', 86): {'IA_AVERAGE_FIX_PUPIL_SIZE': 1291.55,
#   'IA_MAX_FIX_PUPIL_SIZE': 1307.4,
#   'IA_MIN_FIX_PUPIL_SIZE': 1279.3,
#   'Pupilsize_variation': 28.1,
#   'IA_FIRST_FIXATION_DURATION': 230.6,
#   'IA_SECOND_FIXATION_DURATION': 204.4,
#   'IA_SECOND_RUN_FIXATION_%': 0.04618,
#   'IA_FIRST_RUN_FIXATION_%': 0.04234,
#   'IA_REGRESSION_IN': 0,
#   'IA_RUN_COUNT': 0,
#   'IA_REGRESSION_IN_COUNT': 0,
#   'IA_REGRESSION_OUT': 0,
#   'IA_REGRESSION_OUT_COUNT': 0,
#   'backward_reg_count': 0,
#   'forward_reg_count': 0,
#   'total_reg_count': 0,
#   'backward_reg_list': [],
#   'forward_reg_list': [],
#   'total_reg_list': []},
#  ('p2', 87): {'IA_AVERAGE_FIX_PUPIL_SIZE': 1338.1966666666667,
#   'IA_MAX_FIX_PUPIL_SIZE': 1381.6666666666667,
#   'IA_MIN_FIX_PUPIL_SIZE': 1289.8333333333333,
#   'Pupilsize_variation': 91.83333333333333,
#   'IA_FIRST_FIXATION_DURATION': 217.83333333333334,
#   'IA_SECOND_FIXATION_DURATION': 284.2,
#   'IA_SECOND_RUN_FIXATION_%': 0.05685,
#   'IA_FIRST_RUN_FIXATION_%': 0.09093333333333332,
#   'IA_REGRESSION_IN': 0,
#   'IA_RUN_COUNT': 0,
#   'IA_REGRESSION_IN_COUNT': 0,
#   'IA_REGRESSION_OUT': 0,
#   'IA_REGRESSION_OUT_COUNT': 0,
#   'backward_reg_count': 0,
#   'forward_reg_count': 0,
#   'total_reg_count': 0,
#   'backward_reg_list': [],
#   'forward_reg_list': [],
#   'total_reg_list': []},
#  ('p2', 88): {'IA_AVERAGE_FIX_PUPIL_SIZE': 1428.642857142857,
#   'IA_MAX_FIX_PUPIL_SIZE': 1440.0,
#   'IA_MIN_FIX_PUPIL_SIZE': 1418.7142857142858,
#   'Pupilsize_variation': 21.285714285714285,
#   'IA_FIRST_FIXATION_DURATION': 272.14285714285717,
#   'IA_SECOND_FIXATION_DURATION': 137.5,
#   'IA_SECOND_RUN_FIXATION_%': 0.0714,
#   'IA_FIRST_RUN_FIXATION_%': 0.08161428571428572,
#   'IA_REGRESSION_IN': 0,
#   'IA_RUN_COUNT': 0,
#   'IA_REGRESSION_IN_COUNT': 0,
#   'IA_REGRESSION_OUT': 0,
#   'IA_REGRESSION_OUT_COUNT': 0,
#   'backward_reg_count': 0,
#   'forward_reg_count': 0,
#   'total_reg_count': 0,
#   'backward_reg_list': [],
#   'forward_reg_list': [],
#   'total_reg_list': []},
#  ('p2', 89): {'IA_AVERAGE_FIX_PUPIL_SIZE': 1401.3,
#   'IA_MAX_FIX_PUPIL_SIZE': 1410.4,
#   'IA_MIN_FIX_PUPIL_SIZE': 1392.2,
#   'Pupilsize_variation': 18.2,
#   'IA_FIRST_FIXATION_DURATION': 216.4,
#   'IA_SECOND_FIXATION_DURATION': 253.0,
#   'IA_SECOND_RUN_FIXATION_%': 0.0625,
#   'IA_FIRST_RUN_FIXATION_%': 0.075,
#   'IA_REGRESSION_IN': 0,
#   'IA_RUN_COUNT': 0,
#   'IA_REGRESSION_IN_COUNT': 0,
#   'IA_REGRESSION_OUT': 0,
#   'IA_REGRESSION_OUT_COUNT': 0,
#   'backward_reg_count': 0,
#   'forward_reg_count': 0,
#   'total_reg_count': 0,
#   'backward_reg_list': [],
#   'forward_reg_list': [],
#   'total_reg_list': []},
#  ('p2', 90): {'IA_AVERAGE_FIX_PUPIL_SIZE': 1358.5,
#   'IA_MAX_FIX_PUPIL_SIZE': 1358.5,
#   'IA_MIN_FIX_PUPIL_SIZE': 1358.5,
#   'Pupilsize_variation': 0.0,
#   'IA_FIRST_FIXATION_DURATION': 142.0,
#   'IA_SECOND_FIXATION_DURATION': nan,
#   'IA_SECOND_RUN_FIXATION_%': nan,
#   'IA_FIRST_RUN_FIXATION_%': 0.1429,
#   'IA_REGRESSION_IN': 0,
#   'IA_RUN_COUNT': 0,
#   'IA_REGRESSION_IN_COUNT': 0,
#   'IA_REGRESSION_OUT': 0,
#   'IA_REGRESSION_OUT_COUNT': 0,
#   'backward_reg_count': 0,
#   'forward_reg_count': 0,
#   'total_reg_count': 0,
#   'backward_reg_list': [],
#   'forward_reg_list': [],
#   'total_reg_list': []},
#  ('p2', 91): {'IA_AVERAGE_FIX_PUPIL_SIZE': 1312.555,
#   'IA_MAX_FIX_PUPIL_SIZE': 1326.1666666666667,
#   'IA_MIN_FIX_PUPIL_SIZE': 1299.3333333333333,
#   'Pupilsize_variation': 26.833333333333332,
#   'IA_FIRST_FIXATION_DURATION': 223.16666666666666,
#   'IA_SECOND_FIXATION_DURATION': 194.75,
#   'IA_SECOND_RUN_FIXATION_%': 0.0625,
#   'IA_FIRST_RUN_FIXATION_%': 0.11458333333333333,
#   'IA_REGRESSION_IN': 0,
#   'IA_RUN_COUNT': 0,
#   'IA_REGRESSION_IN_COUNT': 0,
#   'IA_REGRESSION_OUT': 0,
#   'IA_REGRESSION_OUT_COUNT': 0,
#   'backward_reg_count': 0,
#   'forward_reg_count': 0,
#   'total_reg_count': 0,
#   'backward_reg_list': [],
#   'forward_reg_list': [],
#   'total_reg_list': []},
#  ('p2', 92): {'IA_AVERAGE_FIX_PUPIL_SIZE': 1337.2633333333333,
#   'IA_MAX_FIX_PUPIL_SIZE': 1364.6666666666667,
#   'IA_MIN_FIX_PUPIL_SIZE': 1298.8333333333333,
#   'Pupilsize_variation': 65.83333333333333,
#   'IA_FIRST_FIXATION_DURATION': 254.83333333333334,
#   'IA_SECOND_FIXATION_DURATION': 210.0,
#   'IA_SECOND_RUN_FIXATION_%': 0.04,
#   'IA_FIRST_RUN_FIXATION_%': 0.04666666666666666,
#   'IA_REGRESSION_IN': 0,
#   'IA_RUN_COUNT': 0,
#   'IA_REGRESSION_IN_COUNT': 0,
#   'IA_REGRESSION_OUT': 0,
#   'IA_REGRESSION_OUT_COUNT': 0,
#   'backward_reg_count': 0,
#   'forward_reg_count': 0,
#   'total_reg_count': 0,
#   'backward_reg_list': [],
#   'forward_reg_list': [],
#   'total_reg_list': []},
#  ('p2', 93): {'IA_AVERAGE_FIX_PUPIL_SIZE': 1388.0,
#   'IA_MAX_FIX_PUPIL_SIZE': 1401.4,
#   'IA_MIN_FIX_PUPIL_SIZE': 1375.8,
#   'Pupilsize_variation': 25.6,
#   'IA_FIRST_FIXATION_DURATION': 223.4,
#   'IA_SECOND_FIXATION_DURATION': 207.0,
#   'IA_SECOND_RUN_FIXATION_%': 0.0769,
#   'IA_FIRST_RUN_FIXATION_%': 0.15381999999999998,
#   'IA_REGRESSION_IN': 0,
#   'IA_RUN_COUNT': 0,
#   'IA_REGRESSION_IN_COUNT': 0,
#   'IA_REGRESSION_OUT': 0,
#   'IA_REGRESSION_OUT_COUNT': 0,
#   'backward_reg_count': 0,
#   'forward_reg_count': 0,
#   'total_reg_count': 0,
#   'backward_reg_list': [],
#   'forward_reg_list': [],
#   'total_reg_list': []},
#  ('p2', 94): {'IA_AVERAGE_FIX_PUPIL_SIZE': 1278.9633333333334,
#   'IA_MAX_FIX_PUPIL_SIZE': 1295.3333333333333,
#   'IA_MIN_FIX_PUPIL_SIZE': 1262.888888888889,
#   'Pupilsize_variation': 32.44444444444444,
#   'IA_FIRST_FIXATION_DURATION': 247.33333333333334,
#   'IA_SECOND_FIXATION_DURATION': 177.5,
#   'IA_SECOND_RUN_FIXATION_%': 0.0667,
#   'IA_FIRST_RUN_FIXATION_%': 0.08891111111111111,
#   'IA_REGRESSION_IN': 0,
#   'IA_RUN_COUNT': 0,
#   'IA_REGRESSION_IN_COUNT': 0,
#   'IA_REGRESSION_OUT': 0,
#   'IA_REGRESSION_OUT_COUNT': 0,
#   'backward_reg_count': 0,
#   'forward_reg_count': 0,
#   'total_reg_count': 0,
#   'backward_reg_list': [],
#   'forward_reg_list': [],
#   'total_reg_list': []},
#  ('p20', 5): {'IA_AVERAGE_FIX_PUPIL_SIZE': 1601.066,
#   'IA_MAX_FIX_PUPIL_SIZE': 1830.6,
#   'IA_MIN_FIX_PUPIL_SIZE': 1391.2,
#   'Pupilsize_variation': 439.4,
#   'IA_FIRST_FIXATION_DURATION': 199.4,
#   'IA_SECOND_FIXATION_DURATION': 200.8,
#   'IA_SECOND_RUN_FIXATION_%': 0.036820000000000006,
#   'IA_FIRST_RUN_FIXATION_%': 0.0263,
#   'IA_REGRESSION_IN': 0,
#   'IA_RUN_COUNT': 0,
#   'IA_REGRESSION_IN_COUNT': 0,
#   'IA_REGRESSION_OUT': 0,
#   'IA_REGRESSION_OUT_COUNT': 0,
#   'backward_reg_count': 0,
#   'forward_reg_count': 0,
#   'total_reg_count': 0,
#   'backward_reg_list': [],
#   'forward_reg_list': [],
#   'total_reg_list': []},
#  ('p20', 6): {'IA_AVERAGE_FIX_PUPIL_SIZE': 1328.9666666666667,
#   'IA_MAX_FIX_PUPIL_SIZE': 1597.8333333333333,
#   'IA_MIN_FIX_PUPIL_SIZE': 1150.6666666666667,
#   'Pupilsize_variation': 447.1666666666667,
#   'IA_FIRST_FIXATION_DURATION': 236.5,
#   'IA_SECOND_FIXATION_DURATION': 177.66666666666666,
#   'IA_SECOND_RUN_FIXATION_%': 0.048499999999999995,
#   'IA_FIRST_RUN_FIXATION_%': 0.0273,
#   'IA_REGRESSION_IN': 0,
#   'IA_RUN_COUNT': 0,
#   'IA_REGRESSION_IN_COUNT': 0,
#   'IA_REGRESSION_OUT': 0,
#   'IA_REGRESSION_OUT_COUNT': 0,
#   'backward_reg_count': 0,
#   'forward_reg_count': 0,
#   'total_reg_count': 0,
#   'backward_reg_list': [],
#   'forward_reg_list': [],
#   'total_reg_list': []},
#  ('p20', 7): {'IA_AVERAGE_FIX_PUPIL_SIZE': 1305.9085714285716,
#   'IA_MAX_FIX_PUPIL_SIZE': 1445.2857142857142,
#   'IA_MIN_FIX_PUPIL_SIZE': 1143.7142857142858,
#   'Pupilsize_variation': 301.57142857142856,
#   'IA_FIRST_FIXATION_DURATION': 224.71428571428572,
#   'IA_SECOND_FIXATION_DURATION': 191.28571428571428,
#   'IA_SECOND_RUN_FIXATION_%': 0.022857142857142854,
#   'IA_FIRST_RUN_FIXATION_%': 0.03142857142857143,
#   'IA_REGRESSION_IN': 0,
#   'IA_RUN_COUNT': 0,
#   'IA_REGRESSION_IN_COUNT': 0,
#   'IA_REGRESSION_OUT': 0,
#   'IA_REGRESSION_OUT_COUNT': 0,
#   'backward_reg_count': 0,
#   'forward_reg_count': 0,
#   'total_reg_count': 0,
#   'backward_reg_list': [],
#   'forward_reg_list': [],
#   'total_reg_list': []},
#  ('p20', 8): {'IA_AVERAGE_FIX_PUPIL_SIZE': 1341.6875,
#   'IA_MAX_FIX_PUPIL_SIZE': 1386.75,
#   'IA_MIN_FIX_PUPIL_SIZE': 1300.5,
#   'Pupilsize_variation': 86.25,
#   'IA_FIRST_FIXATION_DURATION': 158.75,
#   'IA_SECOND_FIXATION_DURATION': 198.5,
#   'IA_SECOND_RUN_FIXATION_%': 0.0625,
#   'IA_FIRST_RUN_FIXATION_%': 0.0625,
#   'IA_REGRESSION_IN': 0,
#   'IA_RUN_COUNT': 0,
#   'IA_REGRESSION_IN_COUNT': 0,
#   'IA_REGRESSION_OUT': 0,
#   'IA_REGRESSION_OUT_COUNT': 0,
#   'backward_reg_count': 0,
#   'forward_reg_count': 0,
#   'total_reg_count': 0,
#   'backward_reg_list': [],
#   'forward_reg_list': [],
#   'total_reg_list': []},
#  ('p20', 9): {'IA_AVERAGE_FIX_PUPIL_SIZE': 1205.655,
#   'IA_MAX_FIX_PUPIL_SIZE': 1356.0,
#   'IA_MIN_FIX_PUPIL_SIZE': 1026.25,
#   'Pupilsize_variation': 329.75,
#   'IA_FIRST_FIXATION_DURATION': 151.25,
#   'IA_SECOND_FIXATION_DURATION': 161.0,
#   'IA_SECOND_RUN_FIXATION_%': 0.037,
#   'IA_FIRST_RUN_FIXATION_%': 0.046275,
#   'IA_REGRESSION_IN': 0,
#   'IA_RUN_COUNT': 0,
#   'IA_REGRESSION_IN_COUNT': 0,
#   'IA_REGRESSION_OUT': 0,
#   'IA_REGRESSION_OUT_COUNT': 0,
#   'backward_reg_count': 0,
#   'forward_reg_count': 0,
#   'total_reg_count': 0,
#   'backward_reg_list': [],
#   'forward_reg_list': [],
#   'total_reg_list': []},
#  ('p20', 10): {'IA_AVERAGE_FIX_PUPIL_SIZE': 1235.1285714285714,
#   'IA_MAX_FIX_PUPIL_SIZE': 1307.5714285714287,
#   'IA_MIN_FIX_PUPIL_SIZE': 1162.857142857143,
#   'Pupilsize_variation': 144.71428571428572,
#   'IA_FIRST_FIXATION_DURATION': 146.14285714285714,
#   'IA_SECOND_FIXATION_DURATION': 159.57142857142858,
#   'IA_SECOND_RUN_FIXATION_%': 0.0323,
#   'IA_FIRST_RUN_FIXATION_%': 0.0369,
#   'IA_REGRESSION_IN': 0,
#   'IA_RUN_COUNT': 0,
#   'IA_REGRESSION_IN_COUNT': 0,
#   'IA_REGRESSION_OUT': 0,
#   'IA_REGRESSION_OUT_COUNT': 0,
#   'backward_reg_count': 0,
#   'forward_reg_count': 0,
#   'total_reg_count': 0,
#   'backward_reg_list': [],
#   'forward_reg_list': [],
#   'total_reg_list': []},
#  ('p20', 11): {'IA_AVERAGE_FIX_PUPIL_SIZE': 1193.8733333333332,
#   'IA_MAX_FIX_PUPIL_SIZE': 1350.1666666666667,
#   'IA_MIN_FIX_PUPIL_SIZE': 1073.0,
#   'Pupilsize_variation': 277.1666666666667,
#   'IA_FIRST_FIXATION_DURATION': 166.16666666666666,
#   'IA_SECOND_FIXATION_DURATION': 162.6,
#   'IA_SECOND_RUN_FIXATION_%': 0.04152,
#   'IA_FIRST_RUN_FIXATION_%': 0.031466666666666664,
#   'IA_REGRESSION_IN': 0,
#   'IA_RUN_COUNT': 0,
#   'IA_REGRESSION_IN_COUNT': 0,
#   'IA_REGRESSION_OUT': 0,
#   'IA_REGRESSION_OUT_COUNT': 0,
#   'backward_reg_count': 0,
#   'forward_reg_count': 0,
#   'total_reg_count': 0,
#   'backward_reg_list': [],
#   'forward_reg_list': [],
#   'total_reg_list': []},
#  ('p20', 12): {'IA_AVERAGE_FIX_PUPIL_SIZE': 1339.7649999999999,
#   'IA_MAX_FIX_PUPIL_SIZE': 1487.3333333333333,
#   'IA_MIN_FIX_PUPIL_SIZE': 1214.6666666666667,
#   'Pupilsize_variation': 272.6666666666667,
#   'IA_FIRST_FIXATION_DURATION': 185.66666666666666,
#   'IA_SECOND_FIXATION_DURATION': 180.0,
#   'IA_SECOND_RUN_FIXATION_%': 0.03641666666666667,
#   'IA_FIRST_RUN_FIXATION_%': 0.03641666666666667,
#   'IA_REGRESSION_IN': 0,
#   'IA_RUN_COUNT': 0,
#   'IA_REGRESSION_IN_COUNT': 0,
#   'IA_REGRESSION_OUT': 0,
#   'IA_REGRESSION_OUT_COUNT': 0,
#   'backward_reg_count': 0,
#   'forward_reg_count': 0,
#   'total_reg_count': 0,
#   'backward_reg_list': [],
#   'forward_reg_list': [],
#   'total_reg_list': []},
#  ('p20', 13): {'IA_AVERAGE_FIX_PUPIL_SIZE': 1224.2775,
#   'IA_MAX_FIX_PUPIL_SIZE': 1447.5,
#   'IA_MIN_FIX_PUPIL_SIZE': 1046.875,
#   'Pupilsize_variation': 400.625,
#   'IA_FIRST_FIXATION_DURATION': 172.375,
#   'IA_SECOND_FIXATION_DURATION': 158.625,
#   'IA_SECOND_RUN_FIXATION_%': 0.020812499999999998,
#   'IA_FIRST_RUN_FIXATION_%': 0.023125,
#   'IA_REGRESSION_IN': 0,
#   'IA_RUN_COUNT': 0,
#   'IA_REGRESSION_IN_COUNT': 0,
#   'IA_REGRESSION_OUT': 0,
#   'IA_REGRESSION_OUT_COUNT': 0,
#   'backward_reg_count': 0,
#   'forward_reg_count': 0,
#   'total_reg_count': 0,
#   'backward_reg_list': [],
#   'forward_reg_list': [],
#   'total_reg_list': []},
#  ('p20', 14): {'IA_AVERAGE_FIX_PUPIL_SIZE': 1293.6516666666666,
#   'IA_MAX_FIX_PUPIL_SIZE': 1351.6666666666667,
#   'IA_MIN_FIX_PUPIL_SIZE': 1212.3333333333333,
#   'Pupilsize_variation': 139.33333333333334,
#   'IA_FIRST_FIXATION_DURATION': 186.33333333333334,
#   'IA_SECOND_FIXATION_DURATION': 195.5,
#   'IA_SECOND_RUN_FIXATION_%': 0.049999999999999996,
#   'IA_FIRST_RUN_FIXATION_%': 0.05833333333333333,
#   'IA_REGRESSION_IN': 0,
#   'IA_RUN_COUNT': 0,
#   'IA_REGRESSION_IN_COUNT': 0,
#   'IA_REGRESSION_OUT': 0,
#   'IA_REGRESSION_OUT_COUNT': 0,
#   'backward_reg_count': 0,
#   'forward_reg_count': 0,
#   'total_reg_count': 0,
#   'backward_reg_list': [],
#   'forward_reg_list': [],
#   'total_reg_list': []},
#  ...}

# %%
to_change_values_dict['p1', 6]
# Out:
# {'IA_AVERAGE_FIX_PUPIL_SIZE': 923.5714285714286,
#  'IA_MAX_FIX_PUPIL_SIZE': 959.8571428571429,
#  'IA_MIN_FIX_PUPIL_SIZE': 893.2857142857143,
#  'Pupilsize_variation': 66.57142857142857,
#  'IA_FIRST_FIXATION_DURATION': 162.57142857142858,
#  'IA_SECOND_FIXATION_DURATION': 215.4,
#  'IA_SECOND_RUN_FIXATION_%': 0.055600000000000004,
#  'IA_FIRST_RUN_FIXATION_%': 0.06352857142857142,
#  'IA_REGRESSION_IN': 0,
#  'IA_RUN_COUNT': 0,
#  'IA_REGRESSION_IN_COUNT': 0,
#  'IA_REGRESSION_OUT': 0,
#  'IA_REGRESSION_OUT_COUNT': 0,
#  'backward_reg_count': 0,
#  'forward_reg_count': 0,
#  'total_reg_count': 0,
#  'backward_reg_list': [],
#  'forward_reg_list': [],
#  'total_reg_list': []}

# %%
to_remove_index = []
for index, row in  gaze_df.iterrows():
    
    ##check the rows with NaN in one of these columns and replace it with mean or zero value depending on the parameter
    if row['IA_DWELL_TIME']==0:
        
        pno= row['RECORDING_SESSION_LABEL']
        tno= row['TRIAL_INDEX']
        #print(pno, tno)
        for key, value in to_change_values_dict[pno,tno].items():

            gaze_df.at[index,key]= value
            
        ##if it is still nan this means that no fixation at all for the sentence
        #if  pd.isnull( row['IA_AVERAGE_FIX_PUPIL_SIZE']) == True:
        #    to_remove_index.append(index)   
gaze_df.to_csv('gaze_word_level.csv', index=False)

# %%
print('DF Length: ', len(gaze_df))
# Out:
# DF Length:  27649

# %%
## Maximum IA count in the dataset for padding
gaze_df['TRIAL_IA_COUNT'].max(), gaze_df['TRIAL_IA_COUNT'].min()
# Out:
# (29, 6)

# %%
gaze_df['token']
# Out:
# 0               frauen
# 1                haben
# 2                einen
# 3          signifikant
# 4           geringeren
#              ...
# 27644             sind
# 27645    minderleister
# 27646               in
# 27647          unserer
# 27648     gesellschaft
# Name: token, Length: 27649, dtype: object

# %% [markdown]
# ------------------------
